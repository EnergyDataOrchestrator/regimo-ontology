# %%
from rdmo_client import Client

BASE_URL = 'http://localhost:8484'
AUTH = ('rdmo', 'rdmo')
TOKEN = '106cac9b5072b7dcfce4c96a2f52cb302b79fb20'
URI_PREFIX = 'https://rdmorganiser.github.io/terms/'

client = Client(BASE_URL, auth=AUTH)

# %%
client.list_project_values(1, attribute=82)
# Out:
# []

# %%
client.list_values(attribute=82)
# Out:
# []

# %%
client.resolve_project_condition(1, 10)
# Out:
# {'result': False}

# %%
client.list_projects()
# Out:
# {'count': 7,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 1,
#    'title': 'Harmony with RDMO catalog',
#    'description': 'Part of the harmony task force in HMC.',
#    'catalog': 5,
#    'catalog_uri': 'https://rdmorganiser.github.io/terms/questions/rdmo',
#    'snapshots': [2, 1],
#    'parent': None,
#    'owners': [{'id': 1,
#      'username': 'mohamed.koubaa@kit.edu',
#      'first_name': 'Anis',
#      'last_name': 'Koubaa',
#      'full_name': 'Anis Koubaa',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-01-21T04:34:44.267221+01:00',
#    'updated': '2026-01-21T05:19:11.024927+01:00',
#    'last_changed': '2026-06-15T08:50:54.449422+02:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 111,
#    'progress_count': 57,
#    'visibility': None},
#   {'id': 7,
#    'title': 'metadata_analysis_01',
#    'description': 'The analysis has a heat map as output, where the concordance of metadata to the Dublin core is presented.',
#    'catalog': 5,
#    'catalog_uri': 'https://rdmorganiser.github.io/terms/questions/rdmo',
#    'snapshots': [],
#    'parent': 1,
#    'owners': [{'id': 1,
#      'username': 'mohamed.koubaa@kit.edu',
#      'first_name': 'Anis',
#      'last_name': 'Koubaa',
#      'full_name': 'Anis Koubaa',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-03-02T10:59:21.199975+01:00',
#    'updated': '2026-06-15T09:04:47.912142+02:00',
#    'last_changed': '2026-06-15T09:04:47.912142+02:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 108,
#    'progress_count': 54,
#    'visibility': None},
#   {'id': 3,
#    'title': 'IAI',
#    'description': 'Institute for Automation and Informatics.',
#    'catalog': 3,
#    'catalog_uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort',
#    'snapshots': [],
#    'parent': None,
#    'owners': [{'id': 1,
#      'username': 'mohamed.koubaa@kit.edu',
#      'first_name': 'Anis',
#      'last_name': 'Koubaa',
#      'full_name': 'Anis Koubaa',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-02-22T01:25:56.978132+01:00',
#    'updated': '2026-06-15T08:37:25.463029+02:00',
#    'last_changed': '2026-06-15T08:37:25.463029+02:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 34,
#    'progress_count': 23,
#    'visibility': None},
#   {'id': 4,
#    'title': 'IAI',
#    'description': 'Institute for Automation and Informatics',
#    'catalog': None,
#    'catalog_uri': None,
#    'snapshots': [],
#    'parent': None,
#    'owners': [{'id': 2,
#      'username': 'rdmo',
#      'first_name': '',
#      'last_name': '',
#      'full_name': 'rdmo',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-02-25T18:07:24.322569+01:00',
#    'updated': '2026-02-25T18:07:35.790736+01:00',
#    'last_changed': '2026-02-25T18:07:35.790736+01:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 0,
#    'progress_count': 0,
#    'visibility': None},
#   {'id': 6,
#    'title': 'Measurement_02',
#    'description': 'Second Measurement',
#    'catalog': None,
#    'catalog_uri': None,
#    'snapshots': [],
#    'parent': 4,
#    'owners': [{'id': 2,
#      'username': 'rdmo',
#      'first_name': '',
#      'last_name': '',
#      'full_name': 'rdmo',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-03-02T10:54:14.726258+01:00',
#    'updated': '2026-03-02T10:54:31.554320+01:00',
#    'last_changed': '2026-03-02T10:54:31.554320+01:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 0,
#    'progress_count': 0,
#    'visibility': None},
#   {'id': 5,
#    'title': 'Measurement_01',
#    'description': 'First Measurement',
#    'catalog': None,
#    'catalog_uri': None,
#    'snapshots': [],
#    'parent': None,
#    'owners': [{'id': 2,
#      'username': 'rdmo',
#      'first_name': '',
#      'last_name': '',
#      'full_name': 'rdmo',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-03-02T10:53:07.656664+01:00',
#    'updated': '2026-06-17T17:22:14.094323+02:00',
#    'last_changed': '2026-06-17T17:22:14.094323+02:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 2,
#    'progress_count': 2,
#    'visibility': None},
#   {'id': 9,
#    'title': 'test',
#    'description': 'test',
#    'catalog': None,
#    'catalog_uri': None,
#    'snapshots': [],
#    'parent': None,
#    'owners': [{'id': 1,
#      'username': 'mohamed.koubaa@kit.edu',
#      'first_name': 'Anis',
#      'last_name': 'Koubaa',
#      'full_name': 'Anis Koubaa',
#      'email': 'mohamed.koubaa@kit.edu'}],
#    'managers': [],
#    'authors': [],
#    'guests': [],
#    'created': '2026-06-15T19:20:03.233304+02:00',
#    'updated': '2026-06-15T19:20:05.421301+02:00',
#    'last_changed': '2026-06-15T19:20:05.421301+02:00',
#    'site': 1,
#    'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#    'progress_total': 0,
#    'progress_count': 0,
#    'visibility': None}]}

# %%
client.retrieve_project(1)
# Out:
# {'id': 1,
#  'title': 'Harmony with RDMO catalog',
#  'description': 'Part of the harmony task force in HMC.',
#  'catalog': 5,
#  'catalog_uri': 'https://rdmorganiser.github.io/terms/questions/rdmo',
#  'snapshots': [2, 1],
#  'parent': None,
#  'owners': [{'id': 1,
#    'username': 'mohamed.koubaa@kit.edu',
#    'first_name': 'Anis',
#    'last_name': 'Koubaa',
#    'full_name': 'Anis Koubaa',
#    'email': 'mohamed.koubaa@kit.edu'}],
#  'managers': [],
#  'authors': [],
#  'guests': [],
#  'created': '2026-01-21T04:34:44.267221+01:00',
#  'updated': '2026-01-21T05:19:11.024927+01:00',
#  'last_changed': '2026-06-15T08:50:54.449422+02:00',
#  'site': 1,
#  'views': [1, 2, 3, 4, 6, 7, 9, 8, 10, 11],
#  'progress_total': 111,
#  'progress_count': 57,
#  'visibility': None}

# %%
client.create_project({
    'user': 1,
    'catalog': 1,
    'title': 'FOO'
})
# Out:
# {'id': 10,
#  'title': 'FOO',
#  'description': '',
#  'catalog': 1,
#  'catalog_uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste',
#  'snapshots': [],
#  'parent': None,
#  'owners': [{'id': 2,
#    'username': 'rdmo',
#    'first_name': '',
#    'last_name': '',
#    'full_name': 'rdmo',
#    'email': 'mohamed.koubaa@kit.edu'}],
#  'managers': [],
#  'authors': [],
#  'guests': [],
#  'created': '2026-06-30T14:52:21.636701+02:00',
#  'updated': '2026-06-30T14:52:21.636703+02:00',
#  'site': 1,
#  'views': [1, 2, 3, 4, 5, 6, 7, 9, 8, 10, 11],
#  'progress_total': None,
#  'progress_count': None,
#  'visibility': None}
