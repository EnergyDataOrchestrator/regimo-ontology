# %%
from rdmo_client import Client

BASE_URL = 'http://localhost:8484'
AUTH = ('rdmo', 'rdmo')
TOKEN = '106cac9b5072b7dcfce4c96a2f52cb302b79fb20'
URI_PREFIX = 'https://rdmorganiser.github.io/terms/'

client = Client(BASE_URL, auth=AUTH)

# %%
client.index_conditions()
# Out:
# [{'id': 24,
#   'uri': 'https://github.com/RDA-DMP-Common/conditions/has_ethical_issues'},
#  {'id': 23,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/additional_rdm_policy'},
#  {'id': 22,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/application-class-1'},
#  {'id': 21,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/application-class-2'},
#  {'id': 20,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/application-class-3'},
#  {'id': 19,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/costs_relevant'},
#  {'id': 18,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/data_published'},
#  {'id': 17,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/data_sharing'},
#  {'id': 16, 'uri': 'https://rdmorganiser.github.io/terms/conditions/embargo'},
#  {'id': 15,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/infrastructure_resources'},
#  {'id': 14,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/intellectual_property_rights'},
#  {'id': 13,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/international'},
#  {'id': 12,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/law_international'},
#  {'id': 11,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/long_term_preservation'},
#  {'id': 10,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/other_sensitive_data'},
#  {'id': 9,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/personal_data'},
#  {'id': 8,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/personal_inf_bdsg_3_9'},
#  {'id': 7,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/publish-software'},
#  {'id': 6,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/repository_extern'},
#  {'id': 5,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/reuse_scenario'},
#  {'id': 4,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/rights_owner_clear'},
#  {'id': 3,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/rights_owner_unclear'},
#  {'id': 2,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/usage_support'},
#  {'id': 1,
#   'uri': 'https://rdmorganiser.github.io/terms/conditions/versioning_tool_undecided'}]

# %%
client.retrieve_condition(13)
# Out:
# {'id': 13,
#  'model': 'conditions.condition',
#  'uri': 'https://rdmorganiser.github.io/terms/conditions/international',
#  'uri_prefix': 'https://rdmorganiser.github.io/terms',
#  'uri_path': 'international',
#  'comment': 'The legal situation of different countries has to be considered.',
#  'locked': False,
#  'editors': [],
#  'source': None,
#  'relation': 'eq',
#  'target_text': '1',
#  'target_option': None,
#  'optionsets': [],
#  'pages': [],
#  'questionsets': [],
#  'questions': [],
#  'tasks': [],
#  'read_only': False}
