# %%
from rdmo_client import Client

BASE_URL = 'http://localhost:8484'
AUTH = ('rdmo', 'rdmo')
TOKEN = '106cac9b5072b7dcfce4c96a2f52cb302b79fb20'
URI_PREFIX = 'https://rdmorganiser.github.io/terms/'

client = Client(BASE_URL, auth=AUTH)

# %%
client.list_tasks()
# Out:
# [{'id': 10,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/clarify_consequences_international_law',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'clarify_consequences_international_law',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [12],
#   'title': 'Konsequenzen verschiedener relevanter Gesetzgebungen klären',
#   'text': 'Setzen Sie sich bitte mit der Rechtsabteilung bzw. einem/r entsprechenden Ansprechpartner/in an Ihrer Institution in Verbindung, um zu klären, ob sich daraus Konsequenzen für Ihr Projekt ergeben und wenn ja, welche dies sind.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': ['https://rdmorganiser.github.io/terms/conditions/law_international'],
#   'projects_count': 8,
#   'title_en': 'Clarify consequences of different international jurisdictions',
#   'text_en': 'Please get in touch with the legal department or a respective contact person at your institution to clarify if this has consequences for the project and its data management and if yes, what consequences these are.',
#   'title_de': 'Konsequenzen verschiedener relevanter Gesetzgebungen klären',
#   'text_de': 'Setzen Sie sich bitte mit der Rechtsabteilung bzw. einem/r entsprechenden Ansprechpartner/in an Ihrer Institution in Verbindung, um zu klären, ob sich daraus Konsequenzen für Ihr Projekt ergeben und wenn ja, welche dies sind.'},
#  {'id': 9,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/contact_data_security_officer',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'contact_data_security_officer',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'Datenschutzbeauftragten bzgl. spezieller Anforderungen kontaktieren.',
#   'text': '<p>Mindestens einer der Datensätze enthält besonders sensible personenbezogene Daten nach BDSG §3, Abs. 9.</p>\n<p>Infomieren Sie sich bitte bei der/dem Datenschutzbeauftragten Ihrer Institution, welche zusätzlichen Schutzmaßnahmen notwendig sind.</p>',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Contact data security officer about special requirements',
#   'text_en': 'At least one of the datasets contains particularly sensitive personal information according ot BDSG § 3, 9.\n\nPlease get in touch with the data protection officer of your institution to check which additional protection measures are necessary.',
#   'title_de': 'Datenschutzbeauftragten bzgl. spezieller Anforderungen kontaktieren.',
#   'text_de': 'Mindestens einer der Datensätze enthält besonders sensible personenbezogene Daten nach BDSG §3, Abs. 9.\n\nInfomieren Sie sich bitte bei der/dem Datenschutzbeauftragten Ihrer Institution, welche zusätzlichen Schutzmaßnahmen notwendig sind.'},
#  {'id': 8,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/contact_IT_department',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'contact_IT_department',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [15],
#   'title': 'IT-Abteilung kontaktieren, um Infrastrukturressourcen zu organisieren',
#   'text': 'Bitte nehmen Sie Kontakt mit der IT-Abteilung auf, um die Bereitstellung der benötigten Infrastrukturressourcen zu organisieren.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': ['https://rdmorganiser.github.io/terms/conditions/infrastructure_resources'],
#   'projects_count': 8,
#   'title_en': 'Contact IT department to acquire infrastructure resources',
#   'text_en': 'Please get in touch with your IT department to arrange that the required infrastructure resources are provided.',
#   'title_de': 'IT-Abteilung kontaktieren, um Infrastrukturressourcen zu organisieren',
#   'text_de': 'Bitte nehmen Sie Kontakt mit der IT-Abteilung auf, um die Bereitstellung der benötigten Infrastrukturressourcen zu organisieren.'},
#  {'id': 11,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/contact_IT_or_data_management_expert',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'contact_IT_or_data_management_expert',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'IT- oder Datenmanagementexpertin/en kontaktieren',
#   'text': 'Bitte kontaktieren Sie Personen mit IT- oder Datenmanagementexpertise, um die notwendige Unterstützung für geplante Datennutzungsszenarien zu erhalten.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Contact IT or data management expert',
#   'text_en': 'Please contact an IT or data management expert to get support in terms of data usage.',
#   'title_de': 'IT- oder Datenmanagementexpertin/en kontaktieren',
#   'text_de': 'Bitte kontaktieren Sie Personen mit IT- oder Datenmanagementexpertise, um die notwendige Unterstützung für geplante Datennutzungsszenarien zu erhalten.'},
#  {'id': 7,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/contact_rights_owner',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'contact_rights_owner',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [4],
#   'title': 'Rechteinhaber/in kontaktieren',
#   'text': 'Prüfen Sie, welche Einschränkungen damit bezüglich der Langzeitarchivierung und Nachnutzung bestehen und ob der/die Rechteinhaberin bereit ist, ggf. die notwendigen Rechte einzuräumen.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': ['https://rdmorganiser.github.io/terms/conditions/rights_owner_clear'],
#   'projects_count': 8,
#   'title_en': 'Contact rights owner',
#   'text_en': 'Clarify, if and how this restricts the possibility of long-term preservation and re-use and if the rights onwer ist willing to grant the necessary rights.',
#   'title_de': 'Rechteinhaber/in kontaktieren',
#   'text_de': 'Prüfen Sie, welche Einschränkungen damit bezüglich der Langzeitarchivierung und Nachnutzung bestehen und ob der/die Rechteinhaberin bereit ist, ggf. die notwendigen Rechte einzuräumen.'},
#  {'id': 6,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/create_data_organisation_policy',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'create_data_organisation_policy',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'Richtlinien zur Datenorganisation erstellen',
#   'text': 'Erstellen Sie eine Richtlinie zur einheitlichen Organisation der Daten im Projekt.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Create data organisation policy',
#   'text_en': 'Create a policy for a consistent data organisation in the project.',
#   'title_de': 'Richtlinien zur Datenorganisation erstellen',
#   'text_de': 'Erstellen Sie eine Richtlinie zur einheitlichen Organisation der Daten im Projekt.'},
#  {'id': 5,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/create_naming_policy',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'create_naming_policy',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'Richtlinie zur Benennung der Daten erstellen',
#   'text': 'Erstellen Sie eine Richtlinie zur einheitlichen Benennung der Daten innerhalb des Projekts.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Create data naming policy',
#   'text_en': 'Create a guideline for a consistent naming of the data within the project.',
#   'title_de': 'Richtlinie zur Benennung der Daten erstellen',
#   'text_de': 'Erstellen Sie eine Richtlinie zur einheitlichen Benennung der Daten innerhalb des Projekts.'},
#  {'id': 4,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/determine_versioning_tool',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'determine_versioning_tool',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [1],
#   'title': 'Versionierungstool bestimmen',
#   'text': 'Legen Sie fest, welches Versionierungstool genutzt werden soll.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': ['https://rdmorganiser.github.io/terms/conditions/versioning_tool_undecided'],
#   'projects_count': 8,
#   'title_en': 'Determine Versioning Tool',
#   'text_en': 'Determine, which versioning tool will be used for the versioning.',
#   'title_de': 'Versionierungstool bestimmen',
#   'text_de': 'Legen Sie fest, welches Versionierungstool genutzt werden soll.'},
#  {'id': 3,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/finish-first-dmp',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'finish-first-dmp',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': 53,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': 90,
#   'conditions': [],
#   'title': 'Ersten DMP abschließen',
#   'text': 'Der erste DMP sollte 3 Monate nach Projektbeginn abgeschlossen sein.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Finish first DMP',
#   'text_en': 'The first DMP should be finished about 3 months after the project has started.',
#   'title_de': 'Ersten DMP abschließen',
#   'text_de': 'Der erste DMP sollte 3 Monate nach Projektbeginn abgeschlossen sein.'},
#  {'id': 2,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/identify_rights_owner',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'identify_rights_owner',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'Rechteinhaber/in recherchieren',
#   'text': 'Identifizeren Sie den/die Rechteinhaber/in und prüfen Sie, ob diese/r bereit ist, die ggf. die für die Langzeitarchivierung und Nachnutzung notwendigen Rechte einzuräumen.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Identify rights owner',
#   'text_en': 'Identify the rights owner and contact him / her to see if the rights necessary for long-term preservation and re-use will be granted.',
#   'title_de': 'Rechteinhaber/in recherchieren',
#   'text_de': 'Identifizeren Sie den/die Rechteinhaber/in und prüfen Sie, ob diese/r bereit ist, die ggf. die für die Langzeitarchivierung und Nachnutzung notwendigen Rechte einzuräumen.'},
#  {'id': 1,
#   'model': 'tasks.task',
#   'uri': 'https://rdmorganiser.github.io/terms/tasks/inform_data_security_officer',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'inform_data_security_officer',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'catalogs': [],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'start_attribute': None,
#   'end_attribute': None,
#   'days_before': None,
#   'days_after': None,
#   'conditions': [],
#   'title': 'Datenschutzbeauftragte/n informieren',
#   'text': 'Mindestens ein Datensatz enthält personenbezogene Daten. Bitte infomieren Sie den oder die zuständige/n Datenschutzbeauftragte/n Ihrer Institution.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'condition_uris': [],
#   'projects_count': 8,
#   'title_en': 'Inform data security officer',
#   'text_en': 'At least one dataset contains personal data. Please contact the data security officer in charge.',
#   'title_de': 'Datenschutzbeauftragte/n informieren',
#   'text_de': 'Mindestens ein Datensatz enthält personenbezogene Daten. Bitte infomieren Sie den oder die zuständige/n Datenschutzbeauftragte/n Ihrer Institution.'}]
