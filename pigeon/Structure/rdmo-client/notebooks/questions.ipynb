# %%
from rdmo_client import Client

BASE_URL = 'http://localhost:8484'
AUTH = ('rdmo', 'rdmo')
TOKEN = '106cac9b5072b7dcfce4c96a2f52cb302b79fb20'
URI_PREFIX = 'https://rdmorganiser.github.io/terms/'

client = Client(BASE_URL, auth=AUTH)

# %%
client.list_catalogs(key='catalog')
# Out:
# [{'id': 7,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf',
#   'comment': 'Fragenkatalog für den Schweizer Nationalfonds',
#   'locked': False,
#   'order': 2,
#   'available': True,
#   'sections': [{'section': 46, 'order': 0},
#    {'section': 45, 'order': 1},
#    {'section': 44, 'order': 2},
#    {'section': 43, 'order': 3},
#    {'section': 42, 'order': 4}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'SNF',
#   'help': '',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 0,
#   'title_en': 'SNF',
#   'help_en': '',
#   'title_de': 'SNF',
#   'help_de': ''},
#  {'id': 1,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste',
#   'comment': '',
#   'locked': False,
#   'order': 30,
#   'available': True,
#   'sections': [{'section': 6, 'order': 0},
#    {'section': 5, 'order': 1},
#    {'section': 4, 'order': 2},
#    {'section': 3, 'order': 3},
#    {'section': 2, 'order': 4},
#    {'section': 1, 'order': 5}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'DFG-Checkliste',
#   'help': 'Katalog entsprechend der DFG-Checkliste vom 21.12.2021. Aktualisiert am 24.06.2025.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 1,
#   'title_en': 'DFG checklist',
#   'help_en': 'Catalog according to the DFG checklist of December 21, 2021. Updated June 24, 2025.',
#   'title_de': 'DFG-Checkliste',
#   'help_de': 'Katalog entsprechend der DFG-Checkliste vom 21.12.2021. Aktualisiert am 24.06.2025.'},
#  {'id': 5,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'sections': [{'section': 36, 'order': 0},
#    {'section': 35, 'order': 1},
#    {'section': 34, 'order': 2},
#    {'section': 33, 'order': 3},
#    {'section': 32, 'order': 4},
#    {'section': 31, 'order': 5},
#    {'section': 30, 'order': 10}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'RDMO',
#   'help': '',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 2,
#   'title_en': 'RDMO',
#   'help_en': '',
#   'title_de': 'RDMO',
#   'help_de': ''},
#  {'id': 4,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe',
#   'comment': 'RDMO questionnaire for the funding framework program "Horizon Europe" (2021-2027) of the European Commission',
#   'locked': False,
#   'order': 5,
#   'available': True,
#   'sections': [{'section': 29, 'order': 0},
#    {'section': 28, 'order': 1},
#    {'section': 27, 'order': 2},
#    {'section': 26, 'order': 3},
#    {'section': 25, 'order': 4},
#    {'section': 24, 'order': 5},
#    {'section': 23, 'order': 6},
#    {'section': 22, 'order': 7}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'Horizon Europe',
#   'help': '<p>Dieser Katalog ist für Forschungsprojekte bestimmt, die durch die Europäische Kommission im Förderprogramm  Horizon Europe finanziert werden. Er ist nach der <a href="https://ec.europa.eu/info/funding-tenders/opportunities/docs/2021-2027/horizon/temp-form/report/data-management-plan_he_en.docx" target=_blank>Vorlage für Datenmanagementplan, Version 1.0 vom 5. Mai 2021</a> zusammengestellt. Einige der EU-Fragen sind in Unterfragen untergliedert. Darüber hinaus besteht bei vielen Fragen die Möglichkeit, die Frage datensatzspezifisch zu beantworten. Für den Output des Datenmanagementplans gibt es eine passende Ansicht, die</p>\n<ul>\n<li>den Datenmanagementplan in der von der EU gewünschten lieferbaren Form ausgibt;</li>\n<li>die ursprünglichen EU-Fragen verwendet;</li>\n<li>automatisch Verweise auf Fragen einfügt, die bereits in ähnlicher Form gestellt wurden.</li>\n</ul>',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 0,
#   'title_en': 'Horizon Europe',
#   'help_en': 'This catalog is intended for research projects funded by EU Horizon Europe. It is compiled according to the <a href="https://ec.europa.eu/info/funding-tenders/opportunities/docs/2021-2027/horizon/temp-form/report/data-management-plan_he_en.docx" target=_blank>Data Management Plan Template, Version 1.0 from May 5, 2021</a>. Some of the EU questions are broken down into sub-questions. In addition, for many questions there is the option of answering the question on a dataset-specific basis. There is a suitable view for the output of the data management plan, which\n\n- outputs the data management plan in the deliverable form desired by the EU;\n- uses the original EU questions;\n- automatically inserts references to questions that have already been asked in a similar form.',
#   'title_de': 'Horizon Europe',
#   'help_de': 'Dieser Katalog ist für Forschungsprojekte bestimmt, die durch die Europäische Kommission im Förderprogramm  Horizon Europe finanziert werden. Er ist nach der <a href="https://ec.europa.eu/info/funding-tenders/opportunities/docs/2021-2027/horizon/temp-form/report/data-management-plan_he_en.docx" target=_blank>Vorlage für Datenmanagementplan, Version 1.0 vom 5. Mai 2021</a> zusammengestellt. Einige der EU-Fragen sind in Unterfragen untergliedert. Darüber hinaus besteht bei vielen Fragen die Möglichkeit, die Frage datensatzspezifisch zu beantworten. Für den Output des Datenmanagementplans gibt es eine passende Ansicht, die\n\n- den Datenmanagementplan in der von der EU gewünschten lieferbaren Form ausgibt;\n- die ursprünglichen EU-Fragen verwendet;\n- automatisch Verweise auf Fragen einfügt, die bereits in ähnlicher Form gestellt wurden.'},
#  {'id': 2,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc',
#   'comment': 'DCC. (2013). Checklist for a Data Management Plan. v.4.0. Edinburgh: Digital Curation',
#   'locked': False,
#   'order': 10,
#   'available': True,
#   'sections': [{'section': 14, 'order': 0},
#    {'section': 13, 'order': 1},
#    {'section': 12, 'order': 2},
#    {'section': 11, 'order': 3},
#    {'section': 10, 'order': 4},
#    {'section': 9, 'order': 5},
#    {'section': 8, 'order': 6},
#    {'section': 7, 'order': 7}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'DCC-Checkliste 4.0',
#   'help': '',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 0,
#   'title_en': 'DCC Checklist 4.0',
#   'help_en': '',
#   'title_de': 'DCC-Checkliste 4.0',
#   'help_de': ''},
#  {'id': 6,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp',
#   'comment': 'This software project management catalogue was developed by the Max Planck Digital Library in 2022. Thanks to all our team colleagues for their support.\nThis SMP template was inspired by some documentation, specially:\n* https://www.software.ac.uk/resources/guides/software-management-plans\n* https://opencarp.org/about/software-management-plan',
#   'locked': False,
#   'order': 98,
#   'available': True,
#   'sections': [{'section': 41, 'order': 0},
#    {'section': 40, 'order': 1},
#    {'section': 39, 'order': 2},
#    {'section': 38, 'order': 3},
#    {'section': 37, 'order': 4}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'Software-Management-Plan für Forschende',
#   'help': 'Dieser Katalog ist für das Management von wissenschaftlichen Software-Projekten. Er unterstützt Wissenschaftler_innen bei der Entwicklung und der Projektorganisation von Software-Entwicklungen durch fünfzig Fragen in unterschiedlichen Themenblöcken. Dies ist Version 3.0.',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 0,
#   'title_en': 'Software Management Plan for Researchers',
#   'help_en': 'This catalogue is for the management of scientific software projects. It supports scientists in the development and project organisation of software developments through fifty questions in different topic blocks. This is version 3.0 of the catalogue.',
#   'title_de': 'Software-Management-Plan für Forschende',
#   'help_de': 'Dieser Katalog ist für das Management von wissenschaftlichen Software-Projekten. Er unterstützt Wissenschaftler_innen bei der Entwicklung und der Projektorganisation von Software-Entwicklungen durch fünfzig Fragen in unterschiedlichen Themenblöcken. Dies ist Version 3.0.'},
#  {'id': 12,
#   'model': 'questions.catalog',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/rda_madmp',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'rda_madmp',
#   'comment': '',
#   'locked': False,
#   'order': 0,
#   'available': True,
#   'sections': [{'section': 57, 'order': 0},
#    {'section': 56, 'order': 1},
#    {'section': 55, 'order': 2},
#    {'section': 54, 'order': 3}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': '',
#   'help': '',
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'projects_count': 0,
#   'title_en': 'RDA Machine-Actionable DMP',
#   'help_en': '',
#   'title_de': '',
#   'help_de': ''},
#  {'id': 3,
#   'model': 'questions.catalog',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort',
#   'comment': 'Ein kurzer Fragenkatalog für die FH Potsdam mit den wichtigstens Fragen',
#   'locked': False,
#   'order': 1,
#   'available': True,
#   'sections': [{'section': 21, 'order': 0},
#    {'section': 20, 'order': 1},
#    {'section': 19, 'order': 2},
#    {'section': 18, 'order': 3},
#    {'section': 17, 'order': 4},
#    {'section': 16, 'order': 5},
#    {'section': 15, 'order': 6}],
#   'sites': [],
#   'editors': [],
#   'groups': [],
#   'title': 'Kurzer Fragenkatalog',
#   'help': '',
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'projects_count': 1,
#   'title_en': 'Brief questionaire',
#   'help_en': '',
#   'title_de': 'Kurzer Fragenkatalog',
#   'help_de': ''}]

# %%
client.list_sections(catalog=1)
# Out:
# [{'id': 57,
#   'model': 'questions.section',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/administrative',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'administrative',
#   'comment': '',
#   'locked': False,
#   'title': '',
#   'short_title': '',
#   'catalogs': [12],
#   'pages': [{'page': 183, 'order': 0}],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'title_en': 'Administrative Data',
#   'short_title_en': '',
#   'title_de': '',
#   'short_title_de': ''},
#  {'id': 54,
#   'model': 'questions.section',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/costs_legal',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'costs_legal',
#   'comment': '',
#   'locked': False,
#   'title': '',
#   'short_title': '',
#   'catalogs': [12],
#   'pages': [{'page': 179, 'order': 0}, {'page': 180, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'title_en': 'Costs & Legal',
#   'short_title_en': '',
#   'title_de': '',
#   'short_title_de': ''},
#  {'id': 56,
#   'model': 'questions.section',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/dataset',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'dataset',
#   'comment': '',
#   'locked': False,
#   'title': '',
#   'short_title': '',
#   'catalogs': [12],
#   'pages': [{'page': 182, 'order': 0}],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'title_en': 'Dataset Description',
#   'short_title_en': '',
#   'title_de': '',
#   'short_title_de': ''},
#  {'id': 55,
#   'model': 'questions.section',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/host_storage',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'host_storage',
#   'comment': '',
#   'locked': False,
#   'title': '',
#   'short_title': '',
#   'catalogs': [12],
#   'pages': [{'page': 181, 'order': 0}],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'title_en': 'Host & Storage',
#   'short_title_en': '',
#   'title_de': '',
#   'short_title_de': ''},
#  {'id': 47,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.dc/instance/questions/data_set_section',
#   'uri_prefix': 'https://rdmo.dc/instance',
#   'uri_path': 'data_set_section',
#   'comment': 'Usable to describe a data-set.',
#   'locked': False,
#   'title': '',
#   'short_title': '',
#   'catalogs': [],
#   'pages': [{'page': 49, 'order': 0}],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'title_en': 'Data-Set Section',
#   'short_title_en': 'Data-Set',
#   'title_de': '',
#   'short_title_de': ''},
#  {'id': 20,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification',
#   'comment': '',
#   'locked': False,
#   'title': 'Inhaltliche Einordnung',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 49, 'order': 1}, {'page': 48, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Content classification',
#   'short_title_en': '',
#   'title_de': 'Inhaltliche Einordnung',
#   'short_title_de': ''},
#  {'id': 18,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenutzung',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 43, 'order': 0},
#    {'page': 42, 'order': 11},
#    {'page': 41, 'order': 12},
#    {'page': 40, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data usage',
#   'short_title_en': '',
#   'title_de': 'Datenutzung',
#   'short_title_de': ''},
#  {'id': 21,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/general',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/general',
#   'comment': '',
#   'locked': False,
#   'title': 'Allgemein',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 55, 'order': 0},
#    {'page': 54, 'order': 1},
#    {'page': 53, 'order': 10},
#    {'page': 52, 'order': 21},
#    {'page': 51, 'order': 30},
#    {'page': 50, 'order': 31}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'General',
#   'short_title_en': '',
#   'title_de': 'Allgemein',
#   'short_title_de': ''},
#  {'id': 16,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/legal-and-ethics',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/legal-and-ethics',
#   'comment': '',
#   'locked': False,
#   'title': 'Rechtliche und ethische Fragen',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 36, 'order': 1},
#    {'page': 35, 'order': 6},
#    {'page': 34, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Legal and ethics',
#   'short_title_en': '',
#   'title_de': 'Rechtliche und ethische Fragen',
#   'short_title_de': ''},
#  {'id': 17,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/metadata-and-referencing',
#   'comment': '',
#   'locked': False,
#   'title': 'Metadaten und Referenzierung',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 39, 'order': 0},
#    {'page': 38, 'order': 10},
#    {'page': 37, 'order': 11}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Metadata and referencing',
#   'short_title_en': '',
#   'title_de': 'Metadaten und Referenzierung',
#   'short_title_de': ''},
#  {'id': 15,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/storage-and-long-term-preservation',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/storage-and-long-term-preservation',
#   'comment': '',
#   'locked': False,
#   'title': 'Speicherung und Langzeitarchivierung',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 33, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Storage and long-term preservation',
#   'short_title_en': '',
#   'title_de': 'Speicherung und Langzeitarchivierung',
#   'short_title_de': ''},
#  {'id': 19,
#   'model': 'questions.section',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/technical-classification',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/technical-classification',
#   'comment': '',
#   'locked': False,
#   'title': 'Technische Einordnung',
#   'short_title': '',
#   'catalogs': [3],
#   'pages': [{'page': 47, 'order': 2},
#    {'page': 46, 'order': 3},
#    {'page': 45, 'order': 4},
#    {'page': 44, 'order': 5}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Technical classification',
#   'short_title_en': '',
#   'title_de': 'Technische Einordnung',
#   'short_title_de': ''},
#  {'id': 14,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/administrative',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/administrative',
#   'comment': '',
#   'locked': False,
#   'title': 'Verwaltungsdaten',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 32, 'order': 1}, {'page': 31, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Administrative Data',
#   'short_title_en': '',
#   'title_de': 'Verwaltungsdaten',
#   'short_title_de': ''},
#  {'id': 13,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection',
#   'comment': '123',
#   'locked': False,
#   'title': 'Datenaufnahme',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 30, 'order': 11},
#    {'page': 29, 'order': 12},
#    {'page': 28, 'order': 22},
#    {'page': 27, 'order': 22}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data Collection',
#   'short_title_en': '',
#   'title_de': 'Datenaufnahme',
#   'short_title_de': ''},
#  {'id': 12,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/documentation_metadata',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/documentation_metadata',
#   'comment': '',
#   'locked': False,
#   'title': 'Dokumentation und Metadaten',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 26, 'order': 11}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Documentation and Metadata',
#   'short_title_en': '',
#   'title_de': 'Dokumentation und Metadaten',
#   'short_title_de': ''},
#  {'id': 11,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/ethics_legal',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/ethics_legal',
#   'comment': '',
#   'locked': False,
#   'title': 'Ethik und Recht',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 25, 'order': 10}, {'page': 24, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Ethics and Legal Compliance',
#   'short_title_en': '',
#   'title_de': 'Ethik und Recht',
#   'short_title_de': ''},
#  {'id': 7,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/responsibilities_resources',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/responsibilities_resources',
#   'comment': '',
#   'locked': False,
#   'title': 'Verantwortlichkeiten und Ressourcen',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 16, 'order': 0}, {'page': 15, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Responsibilities and Resources',
#   'short_title_en': '',
#   'title_de': 'Verantwortlichkeiten und Ressourcen',
#   'short_title_de': ''},
#  {'id': 9,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/selection_preservation',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/selection_preservation',
#   'comment': '',
#   'locked': False,
#   'title': 'Auswahl und Archvierung',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 21, 'order': 10}, {'page': 20, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Selection and Preservation',
#   'short_title_en': '',
#   'title_de': 'Auswahl und Archvierung',
#   'short_title_de': ''},
#  {'id': 8,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/sharing',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/sharing',
#   'comment': '',
#   'locked': False,
#   'title': 'Daten teilen',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 19, 'order': 10},
#    {'page': 18, 'order': 12},
#    {'page': 17, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data Sharing',
#   'short_title_en': '',
#   'title_de': 'Daten teilen',
#   'short_title_de': ''},
#  {'id': 10,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/storage_backup',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/storage_backup',
#   'comment': '',
#   'locked': False,
#   'title': 'Speicherung and Backup',
#   'short_title': '',
#   'catalogs': [2],
#   'pages': [{'page': 23, 'order': 11}, {'page': 22, 'order': 20}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Storage and Backup',
#   'short_title_en': '',
#   'title_de': 'Speicherung and Backup',
#   'short_title_de': ''},
#  {'id': 6,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/data_description',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/data_description',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenbeschreibung',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 14, 'order': 0},
#    {'page': 13, 'order': 1},
#    {'page': 12, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data description',
#   'short_title_en': '',
#   'title_de': 'Datenbeschreibung',
#   'short_title_de': ''},
#  {'id': 5,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/doku_quality',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/doku_quality',
#   'comment': '',
#   'locked': False,
#   'title': 'Dokumentation und Datenqualität',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 11, 'order': 0}, {'page': 10, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Documentation and data quality',
#   'short_title_en': '',
#   'title_de': 'Dokumentation und Datenqualität',
#   'short_title_de': ''},
#  {'id': 2,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/exchange_access',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/exchange_access',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenaustausch und dauerhafte Zugänglichkeit der Daten',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 4, 'order': 0}, {'page': 3, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data exchange and long-term data accessibility',
#   'short_title_en': '',
#   'title_de': 'Datenaustausch und dauerhafte Zugänglichkeit der Daten',
#   'short_title_de': ''},
#  {'id': 1,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/responsibilities',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/responsibilities',
#   'comment': '',
#   'locked': False,
#   'title': 'Verantwortlichkeiten und Ressourcen',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 2, 'order': 0}, {'page': 1, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Responsibilities and resources',
#   'short_title_en': '',
#   'title_de': 'Verantwortlichkeiten und Ressourcen',
#   'short_title_de': ''},
#  {'id': 3,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/rights',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/rights',
#   'comment': '',
#   'locked': False,
#   'title': 'Rechtliche Verpflichtungen und Rahmenbedingungen',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 7, 'order': 0},
#    {'page': 6, 'order': 1},
#    {'page': 5, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Legal obligations and conditions',
#   'short_title_en': '',
#   'title_de': 'Rechtliche Verpflichtungen und Rahmenbedingungen',
#   'short_title_de': ''},
#  {'id': 4,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/storage_backup',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/storage_backup',
#   'comment': '',
#   'locked': False,
#   'title': 'Speicherung und technische Sicherung während des Projektverlaufs',
#   'short_title': '',
#   'catalogs': [1],
#   'pages': [{'page': 9, 'order': 0}, {'page': 8, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Storage and technical protection measures during the project',
#   'short_title_en': '',
#   'title_de': 'Speicherung und technische Sicherung während des Projektverlaufs',
#   'short_title_de': ''},
#  {'id': 28,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/data_summary',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/data_summary',
#   'comment': '',
#   'locked': False,
#   'title': 'Inhaltliche und technische Einordnung',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 82, 'order': 1},
#    {'page': 81, 'order': 2},
#    {'page': 80, 'order': 3},
#    {'page': 79, 'order': 4},
#    {'page': 78, 'order': 5},
#    {'page': 77, 'order': 6}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Disciplinary and and technical classification of data',
#   'short_title_en': '',
#   'title_de': 'Inhaltliche und technische Einordnung',
#   'short_title_de': ''},
#  {'id': 23,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/ethics',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/ethics',
#   'comment': '',
#   'locked': False,
#   'title': 'Ethik',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 63, 'order': 1},
#    {'page': 62, 'order': 2},
#    {'page': 61, 'order': 3},
#    {'page': 60, 'order': 4},
#    {'page': 59, 'order': 5}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Ethics',
#   'short_title_en': '',
#   'title_de': 'Ethik',
#   'short_title_de': ''},
#  {'id': 27,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/fair_data',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/fair_data',
#   'comment': '',
#   'locked': False,
#   'title': 'FAIRe Daten',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 76, 'order': 1},
#    {'page': 75, 'order': 2},
#    {'page': 74, 'order': 3},
#    {'page': 73, 'order': 4},
#    {'page': 72, 'order': 5},
#    {'page': 71, 'order': 6},
#    {'page': 70, 'order': 7}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'FAIR data',
#   'short_title_en': '',
#   'title_de': 'FAIRe Daten',
#   'short_title_de': ''},
#  {'id': 29,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/general',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/general',
#   'comment': '',
#   'locked': False,
#   'title': 'Allgemeines',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 83, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'General',
#   'short_title_en': '',
#   'title_de': 'Allgemeines',
#   'short_title_de': ''},
#  {'id': 26,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/other_research_outputs',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/other_research_outputs',
#   'comment': '',
#   'locked': False,
#   'title': 'Sonstige Forschungsergebnisse',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 69, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Other research outputs',
#   'short_title_en': '',
#   'title_de': 'Sonstige Forschungsergebnisse',
#   'short_title_de': ''},
#  {'id': 22,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/rdm_regulations',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/rdm_regulations',
#   'comment': '',
#   'locked': False,
#   'title': 'Weitere Aspekte',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 58, 'order': 1},
#    {'page': 57, 'order': 2},
#    {'page': 56, 'order': 3}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Other aspects',
#   'short_title_en': '',
#   'title_de': 'Weitere Aspekte',
#   'short_title_de': ''},
#  {'id': 25,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/resources',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/resources',
#   'comment': '',
#   'locked': False,
#   'title': 'Ressourcenallokation',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 68, 'order': 1},
#    {'page': 67, 'order': 2},
#    {'page': 66, 'order': 3},
#    {'page': 65, 'order': 4}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Allocation of resources',
#   'short_title_en': '',
#   'title_de': 'Ressourcenallokation',
#   'short_title_de': ''},
#  {'id': 24,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/horizon-europe/security',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'horizon-europe/security',
#   'comment': '',
#   'locked': False,
#   'title': 'Datensicherheit',
#   'short_title': '',
#   'catalogs': [4],
#   'pages': [{'page': 64, 'order': 1}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data security',
#   'short_title_en': '',
#   'title_de': 'Datensicherheit',
#   'short_title_de': ''},
#  {'id': 35,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/content-classification',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/content-classification',
#   'comment': '',
#   'locked': False,
#   'title': 'Inhaltliche Einordnung',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 119, 'order': 1},
#    {'page': 118, 'order': 2},
#    {'page': 117, 'order': 3},
#    {'page': 116, 'order': 4}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Content classification',
#   'short_title_en': '',
#   'title_de': 'Inhaltliche Einordnung',
#   'short_title_de': ''},
#  {'id': 33,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/data-usage',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/data-usage',
#   'comment': '',
#   'locked': False,
#   'title': 'Datennutzung',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 110, 'order': 0},
#    {'page': 109, 'order': 11},
#    {'page': 108, 'order': 12},
#    {'page': 107, 'order': 51},
#    {'page': 106, 'order': 52},
#    {'page': 105, 'order': 53},
#    {'page': 104, 'order': 61},
#    {'page': 103, 'order': 63},
#    {'page': 102, 'order': 70}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data usage',
#   'short_title_en': '',
#   'title_de': 'Datennutzung',
#   'short_title_de': ''},
#  {'id': 36,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/general',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/general',
#   'comment': '',
#   'locked': False,
#   'title': 'Allgemein',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 126, 'order': 0},
#    {'page': 125, 'order': 1},
#    {'page': 124, 'order': 10},
#    {'page': 123, 'order': 20},
#    {'page': 122, 'order': 21},
#    {'page': 121, 'order': 40},
#    {'page': 120, 'order': 50}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'General',
#   'short_title_en': '',
#   'title_de': 'Allgemein',
#   'short_title_de': ''},
#  {'id': 31,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/legal-and-ethics',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/legal-and-ethics',
#   'comment': '',
#   'locked': False,
#   'title': 'Rechtliche und ethische Fragen',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 96, 'order': 10},
#    {'page': 95, 'order': 21},
#    {'page': 94, 'order': 22},
#    {'page': 93, 'order': 24},
#    {'page': 92, 'order': 26},
#    {'page': 91, 'order': 27},
#    {'page': 90, 'order': 28},
#    {'page': 89, 'order': 30},
#    {'page': 88, 'order': 31},
#    {'page': 87, 'order': 34}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Legal and ethics',
#   'short_title_en': '',
#   'title_de': 'Rechtliche und ethische Fragen',
#   'short_title_de': ''},
#  {'id': 32,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/metadata-and-referencing',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/metadata-and-referencing',
#   'comment': '',
#   'locked': False,
#   'title': 'Metadaten und Referenzierung',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 101, 'order': 10},
#    {'page': 100, 'order': 12},
#    {'page': 99, 'order': 20},
#    {'page': 98, 'order': 21},
#    {'page': 97, 'order': 23}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Metadata and referencing',
#   'short_title_en': '',
#   'title_de': 'Metadaten und Referenzierung',
#   'short_title_de': ''},
#  {'id': 30,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/storage-and-long-term-preservation',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/storage-and-long-term-preservation',
#   'comment': '',
#   'locked': False,
#   'title': 'Speicherung und Langzeitarchivierung',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 86, 'order': 0},
#    {'page': 85, 'order': 11},
#    {'page': 84, 'order': 13}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Storage and long-term preservation',
#   'short_title_en': '',
#   'title_de': 'Speicherung und Langzeitarchivierung',
#   'short_title_de': ''},
#  {'id': 34,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/rdmo/technical-classification',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'rdmo/technical-classification',
#   'comment': '',
#   'locked': False,
#   'title': 'Technische Einordnung',
#   'short_title': '',
#   'catalogs': [5],
#   'pages': [{'page': 115, 'order': 1},
#    {'page': 114, 'order': 2},
#    {'page': 113, 'order': 3},
#    {'page': 112, 'order': 4},
#    {'page': 111, 'order': 5}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Technical classification',
#   'short_title_en': '',
#   'title_de': 'Technische Einordnung',
#   'short_title_de': ''},
#  {'id': 41,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp/general',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp/general',
#   'comment': '',
#   'locked': False,
#   'title': 'Allgemein',
#   'short_title': '',
#   'catalogs': [6],
#   'pages': [{'page': 146, 'order': 0},
#    {'page': 145, 'order': 1},
#    {'page': 144, 'order': 2},
#    {'page': 143, 'order': 3},
#    {'page': 142, 'order': 4}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'General',
#   'short_title_en': '',
#   'title_de': 'Allgemein',
#   'short_title_de': ''},
#  {'id': 37,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp/legal-and-ethics',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp/legal-and-ethics',
#   'comment': '',
#   'locked': False,
#   'title': 'Rechtliche und ethische Fragen',
#   'short_title': '',
#   'catalogs': [6],
#   'pages': [{'page': 129, 'order': 0},
#    {'page': 128, 'order': 1},
#    {'page': 127, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Legal and Ethics',
#   'short_title_en': '',
#   'title_de': 'Rechtliche und ethische Fragen',
#   'short_title_de': ''},
#  {'id': 39,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp/quality-assurance',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp/quality-assurance',
#   'comment': '',
#   'locked': False,
#   'title': 'Qualitätssicherung',
#   'short_title': '',
#   'catalogs': [6],
#   'pages': [{'page': 136, 'order': 0},
#    {'page': 135, 'order': 1},
#    {'page': 134, 'order': 2}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Quality Assurance',
#   'short_title_en': '',
#   'title_de': 'Qualitätssicherung',
#   'short_title_de': ''},
#  {'id': 38,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp/release-and-publish',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp/release-and-publish',
#   'comment': '',
#   'locked': False,
#   'title': 'Release und öffentliche Verfügbarkeit',
#   'short_title': '',
#   'catalogs': [6],
#   'pages': [{'page': 133, 'order': 0},
#    {'page': 132, 'order': 1},
#    {'page': 131, 'order': 2},
#    {'page': 130, 'order': 3}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Release and Publish',
#   'short_title_en': '',
#   'title_de': 'Release und öffentliche Verfügbarkeit',
#   'short_title_de': ''},
#  {'id': 40,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/smp/technical',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'smp/technical',
#   'comment': '',
#   'locked': False,
#   'title': 'Technische Informationen',
#   'short_title': '',
#   'catalogs': [6],
#   'pages': [{'page': 141, 'order': 0},
#    {'page': 140, 'order': 1},
#    {'page': 139, 'order': 2},
#    {'page': 138, 'order': 3},
#    {'page': 137, 'order': 4}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Technical',
#   'short_title_en': '',
#   'title_de': 'Technische Informationen',
#   'short_title_de': ''},
#  {'id': 45,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/content-classification',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/content-classification',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenerhebung und -dokumentation',
#   'short_title': '',
#   'catalogs': [7],
#   'pages': [{'page': 173, 'order': 0},
#    {'page': 172, 'order': 1},
#    {'page': 171, 'order': 3},
#    {'page': 170, 'order': 4},
#    {'page': 169, 'order': 10},
#    {'page': 168, 'order': 11},
#    {'page': 167, 'order': 12},
#    {'page': 166, 'order': 13},
#    {'page': 165, 'order': 14},
#    {'page': 164, 'order': 15},
#    {'page': 163, 'order': 20},
#    {'page': 162, 'order': 21}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data collection and documentation',
#   'short_title_en': '',
#   'title_de': 'Datenerhebung und -dokumentation',
#   'short_title_de': ''},
#  {'id': 42,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/data-usage',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/data-usage',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenaustausch und Weiterverwendug von Daten',
#   'short_title': '',
#   'catalogs': [7],
#   'pages': [{'page': 150, 'order': 1},
#    {'page': 149, 'order': 2},
#    {'page': 148, 'order': 10},
#    {'page': 147, 'order': 11}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data exchange and reuse of data',
#   'short_title_en': '',
#   'title_de': 'Datenaustausch und Weiterverwendug von Daten',
#   'short_title_de': ''},
#  {'id': 46,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/general',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/general',
#   'comment': '',
#   'locked': False,
#   'title': 'Allgemein',
#   'short_title': '',
#   'catalogs': [7],
#   'pages': [{'page': 175, 'order': 20}, {'page': 174, 'order': 21}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'General',
#   'short_title_en': '',
#   'title_de': 'Allgemein',
#   'short_title_de': ''},
#  {'id': 44,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics',
#   'comment': '',
#   'locked': False,
#   'title': 'Ethische, rechtliche und Sicherheitsfragen',
#   'short_title': '',
#   'catalogs': [7],
#   'pages': [{'page': 161, 'order': 0},
#    {'page': 160, 'order': 10},
#    {'page': 159, 'order': 12},
#    {'page': 158, 'order': 14},
#    {'page': 157, 'order': 20},
#    {'page': 156, 'order': 30},
#    {'page': 155, 'order': 31}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Ethics, legal and security questions',
#   'short_title_en': '',
#   'title_de': 'Ethische, rechtliche und Sicherheitsfragen',
#   'short_title_de': ''},
#  {'id': 43,
#   'model': 'questions.section',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation',
#   'comment': '',
#   'locked': False,
#   'title': 'Datenspeicherung und Datenerhalt',
#   'short_title': '',
#   'catalogs': [7],
#   'pages': [{'page': 154, 'order': 0},
#    {'page': 153, 'order': 1},
#    {'page': 152, 'order': 10},
#    {'page': 151, 'order': 11}],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'title_en': 'Data storage and long-term preservation',
#   'short_title_en': '',
#   'title_de': 'Datenspeicherung und Datenerhalt',
#   'short_title_de': ''}]

# %%
client.list_questions(is_collection=False)
# Out:
# [{'id': 477,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/currency',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'currency',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'select',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [179],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Cost Currency',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 481,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/dataset_type',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'dataset_type',
#   'comment': '',
#   'locked': False,
#   'attribute': 320,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'attribute_uri': 'https://github.com/RDA-DMP-Common/domain/dmp/dataset/type',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'What is the type of the dataset? (e.g. Software, Image, Text)',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 479,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/ethics_exists',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'ethics_exists',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Are there any ethical issues?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 480,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/host_url',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'host_url',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Host/Repository URL',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 478,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/license',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'license',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'select',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'What is the dataset license?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 482,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/project_title',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'project_title',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Project Title',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 109,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification/data-dataset/description',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification/data-dataset/description',
#   'comment': '',
#   'locked': False,
#   'attribute': 234,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Um was für einen Datensatz handelt es sich?',
#   'help': '<p>Bitte beschreiben Sie hier kurz, um welchen Datentyp es sich handelt und mit welcher Methode die Daten erhoben oder erstellt wurden, z. B.:</p>\n<ul>\n<li>quantitative Online-Befragung</li>\n<li>3D-Modellierung / digitale Rekonstruktion einer steinzeitlichen Siedlung</li>\n<li>Software, die im Projekt entwickelt wird</li>\n</ul>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [49],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/description',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'What kind of dataset is it?',
#   'help_en': 'Please briefly describe the data type and / or the method used to create or collect the data, for example:\n\n* quantitative online survey\n* 3D model / digital reconstruction of a stone age settlement\n* software developed within the project',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Um was für einen Datensatz handelt es sich?',
#   'help_de': 'Bitte beschreiben Sie hier kurz, um welchen Datentyp es sich handelt und mit welcher Methode die Daten erhoben oder erstellt wurden, z. B.:\n\n* quantitative Online-Befragung\n* 3D-Modellierung / digitale Rekonstruktion einer steinzeitlichen Siedlung\n* Software, die im Projekt entwickelt wird',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 107,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification/data-existing_data/creator_name',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification/data-existing_data/creator_name',
#   'comment': '',
#   'locked': False,
#   'attribute': 255,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wenn nachgenutzt, wer hat den Datensatz erzeugt?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [48],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/creator/name',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'If re-used, who created the dataset?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wenn nachgenutzt, wer hat den Datensatz erzeugt?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 108,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification/data-existing_data/origin',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification/data-existing_data/origin',
#   'comment': '',
#   'locked': False,
#   'attribute': 199,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wird der Datensatz selbst erzeugt oder nachgenutzt?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [48],
#   'questionsets': [],
#   'optionsets': [58],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/origin',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_origin_options'],
#   'text_en': 'Is the dataset being created or re-used?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wird der Datensatz selbst erzeugt oder nachgenutzt?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 106,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification/data-existing_data/uri',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification/data-existing_data/uri',
#   'comment': '',
#   'locked': False,
#   'attribute': 131,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wenn nachgenutzt, unter welcher Adresse, PID oder URL ist der Datensatz verfügbar?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [48],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/uri',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'If re-used, under which address, PID or URL can the dataset be found?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wenn nachgenutzt, unter welcher Adresse, PID oder URL ist der Datensatz verfügbar?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 93,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-sharing-and-re-use-publication/explanation',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-sharing-and-re-use-publication/explanation',
#   'comment': '',
#   'locked': False,
#   'attribute': 150,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wenn nicht, begründen Sie dies bitte und unterscheiden Sie dabei zwischen rechtlichen und/oder vertraglichen Gründen und freiwilligen Einschränkungen.',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [40],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sharing/explanation',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'If no, please explain why not. Please differentiate between legal and contractual reasons and voluntary restrictions.',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wenn nicht, begründen Sie dies bitte und unterscheiden Sie dabei zwischen rechtlichen und/oder vertraglichen Gründen und freiwilligen Einschränkungen.',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 94,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-sharing-and-re-use-publication/yesno',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-sharing-and-re-use-publication/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 144,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [40],
#   'questionsets': [],
#   'optionsets': [55],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sharing/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_sharing_options'],
#   'text_en': 'Will this dataset be published or shared?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 97,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-storage-and-security-data_security/backups',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-storage-and-security-data_security/backups',
#   'comment': '',
#   'locked': False,
#   'attribute': 238,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wie und wie oft werden Backups der Daten erstellt?',
#   'help': 'Die Frage bezieht sich auf Backups während der Zeit, in denen mit den Daten gearbeitet wird. Fragen der Langzeitarchivierung werden gesondert im entsprechenden Abschnitt behandelt.',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [41],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/data_security/backups',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'How and how often will backups of the data be created?',
#   'help_en': 'This question refers to backups while the data is being worked with. Questions of  long-term preservation will be adressed in the respective section.',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wie und wie oft werden Backups der Daten erstellt?',
#   'help_de': 'Die Frage bezieht sich auf Backups während der Zeit, in denen mit den Daten gearbeitet wird. Fragen der Langzeitarchivierung werden gesondert im entsprechenden Abschnitt behandelt.',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 95,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-storage-and-security-data_security/security_measures',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-storage-and-security-data_security/security_measures',
#   'comment': '',
#   'locked': False,
#   'attribute': 236,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Maßnahmen zur Gewährleistung der Datensicherheit werden getroffen (z. B. Schutz vor unbefugtem Zugriff, Datenwiederherstellung, Übertragung sensibler Daten)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [41],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/data_security/security_measures',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Which measures or provisions are in place to ensure data security (e.g. protection against unauthorized access, data recovery, transfer of sensitive data)?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Maßnahmen zur Gewährleistung der Datensicherheit werden getroffen (z. B. Schutz vor unbefugtem Zugriff, Datenwiederherstellung, Übertragung sensibler Daten)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 98,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-storage-and-security-storage/type',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-storage-and-security-storage/type',
#   'comment': '',
#   'locked': False,
#   'attribute': 136,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wo wird der Datensatz während des Projektes gespeichert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [42],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/type',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Where is the dataset stored during the project?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wo wird der Datensatz während des Projektes gespeichert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 100,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/scenarios-usage/infrastructure',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/scenarios-usage/infrastructure',
#   'comment': '',
#   'locked': False,
#   'attribute': 128,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [43],
#   'questionsets': [],
#   'optionsets': [30],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_infrastructure',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/infrastructure_resources'],
#   'text_en': 'To what extent will infrastructure resources be required (e.g. CPU hours, bandwidth, storage space... etc.).',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 99,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/scenarios-usage/support',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/scenarios-usage/support',
#   'comment': '',
#   'locked': False,
#   'attribute': 127,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [43],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_support',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Are there actual or potential usage scenarios that could benefit from support by a data management or IT expert, or that even require such support?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 112,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/general/project-partners-partner/name',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/general/project-partners-partner/name',
#   'comment': '',
#   'locked': False,
#   'attribute': 77,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Projektpartner',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [52],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/partner/name',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Project partner',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Projektpartner',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 113,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/general/project-schedule-schedule/project_end',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/general/project-schedule-schedule/project_end',
#   'comment': '',
#   'locked': False,
#   'attribute': 54,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'date',
#   'value_type': 'datetime',
#   'unit': '',
#   'width': None,
#   'text': 'Wann endet die Projektlaufzeit?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [53],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/schedule/project_end',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'When does the project end?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wann endet die Projektlaufzeit?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 114,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/general/project-schedule-schedule/project_start',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/general/project-schedule-schedule/project_start',
#   'comment': '',
#   'locked': False,
#   'attribute': 53,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'date',
#   'value_type': 'datetime',
#   'unit': '',
#   'width': None,
#   'text': 'Wann beginnt die Projektlaufzeit?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [53],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/schedule/project_start',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'When does the project start?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wann beginnt die Projektlaufzeit?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 116,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/general/topic-title/title',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/general/topic-title/title',
#   'comment': '',
#   'locked': False,
#   'attribute': 56,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wie lautet die primäre Forschungsfrage des Projektes?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [55],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/research_question/title',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'What is the main research question of the project?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wie lautet die primäre Forschungsfrage des Projektes?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 83,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/legal-and-ethics/intellectual-property-rights-yesno/yesno',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/legal-and-ethics/intellectual-property-rights-yesno/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 103,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Werden Daten genutzt und/oder erstellt, die durch Urheber- oder verwandte Schutzrechte geschützt sind?',
#   'help': '<p>Daten oder Software können Urheber- oder anderen Schutzrechten unterliegen. Die Rechtslage kann selbst in der EU von Land zu Land erheblich abweichen.</p>\n<p>In Deutschland sind nach dem Urheberrechtsgesetz (UrhG) Werke der Literatur, Wissenschaft und Kunst, die eine „persönliche geistige Schöpfung“ darstellen, urheberrechtlich geschützt. Der urheberrechtliche Schutz erlischt 70 Jahre nach dem Tod der bzw. des Urheberin/s.\nReine Daten, z. B. Messdaten oder Surveydaten, aber auch Metadaten (bis auf ggf. „beschreibende“ Metadaten) sind hingegen nicht schutzfähig.</p>\n<p>In § 2 nennt das UrhG folgende geschützte Werkarten, wobei die Aufzählung nicht abschließend ist:</p>\n<ul>\n<li>Sprachwerke, wie Schriftwerke, Reden und Computerprogramme</li>\n<li>Werke der Musik</li>\n<li>pantomimische Werke einschließlich Werke der Tanzkunst</li>\n<li>Werke der bildenden Künste einschließlich der Werke der Baukunst und der angewandten Kunst und Entwürfe solcher Werke</li>\n<li>Lichtbildwerke einschließlich der Werke, die ähnlich wie Lichtbildwerke geschaffen werden</li>\n<li>Darstellungen wissenschaftlicher oder technischer Art wie Zeichnungen, Pläne, Karten, Skizzen, Tabellen und plastische Darstellungen.</li>\n</ul>\n<p>Nach § 3 sind auch „Übersetzungen und andere Bearbeitungen“ von Werken geschützt, die persönliche geistige Schöpfungen des Bearbeiters sind“.</p>\n<p>Schließlich sind nach § 4 auch Sammelwerke und Datenbankwerke geschützt, was im Bereich Forschungsdaten durchaus relevant sein kann. Sammelbankwerke werden dabei definiert als „Sammlungen von Werken, Daten oder anderen unabhängigen Elementen, die aufgrund der Auswahl oder Anordnung der Elemente eine persönliche geistige Schöpfung sind“.\nBei einem „Datenbankwerk im Sinne des Gesetzes“ handelt es sich um ein „Sammelwerk, dessen Elemente systematisch oder methodisch angeordnet und einzeln mit Hilfe elektronischer Mittel oder auf andere Weise zugänglich sind“.</p>\n<p>Weitere relevante Schutzrechte können gewerbliche Schutzrechte wie Patente, Gebrauchsmuster, Sortenschutz [bei Pflanzenzüchtungen], Halbleiterschutz, Marken, geographische Herkunftsangaben, eingetragene Designs oder geschäftliche Bezeichnungen sein.</p>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [34],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/legal_aspects/ipr/yesno',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Does the project use and/or produce data that is protected by intellectual or industrial property rights?',
#   'help_en': 'Data or software can be subject to intellectual or industrial property rights. Applicable laws differ broadly even within EU.\n\nAccording to the German copyright law (UrhG) works of literature, scholarship and the arts that can be regarded as a “personal intellectual creation” are protected by copyright. Copyright protection expires 70 years after the death of the copyright holder.\nMere data, e.g. measured data or survey data, and metadata (except in some cases descriptive metadata) are not protected by copyright.\n\n§ 2 of the UrhG lists the following kinds of protected works (list is not concluded):\n* linguistic works such as written works, speeches and computer programs\n* works of music\n* pantomimic works including works of the art of dance\n* works or the fine arts including works of architecture and the applied arts as well as sketches of such works\n* works of photography and cinematography\n* descriptions and illustrations of scholarly or technical nature such as drawings, plans, maps, sketches, tables and three-dimensional represenations\n\nAccording to § 3, copyright is also applicable to translations and other modifications or adaptions of a work if they are individual intellectual creations of the editor.\n\nFinally, according to § 4 copyright also extents to collected editions and database works. Collected editions are “collections of work, data or other independent elements that are individual intellectual creations based on the selection and arrangement of the elements”. Database works are defined as “collected editions, the elements of which are arranged in a systematic or methodical way and can be accessed individually by electronic means or in other ways”.\n\nOther relevant property rights can be trademarks, patents, utility models, plant variety rights protection, integrated circuit layout design protection, geographical indications or registered designs.',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Werden Daten genutzt und/oder erstellt, die durch Urheber- oder verwandte Schutzrechte geschützt sind?',
#   'help_de': 'Daten oder Software können Urheber- oder anderen Schutzrechten unterliegen. Die Rechtslage kann selbst in der EU von Land zu Land erheblich abweichen.\n\nIn Deutschland sind nach dem Urheberrechtsgesetz (UrhG) Werke der Literatur, Wissenschaft und Kunst, die eine „persönliche geistige Schöpfung“ darstellen, urheberrechtlich geschützt. Der urheberrechtliche Schutz erlischt 70 Jahre nach dem Tod der bzw. des Urheberin/s.\nReine Daten, z. B. Messdaten oder Surveydaten, aber auch Metadaten (bis auf ggf. „beschreibende“ Metadaten) sind hingegen nicht schutzfähig.\n\nIn § 2 nennt das UrhG folgende geschützte Werkarten, wobei die Aufzählung nicht abschließend ist:\n\n* Sprachwerke, wie Schriftwerke, Reden und Computerprogramme\n* Werke der Musik\n* pantomimische Werke einschließlich Werke der Tanzkunst\n* Werke der bildenden Künste einschließlich der Werke der Baukunst und der angewandten Kunst und Entwürfe solcher Werke\n* Lichtbildwerke einschließlich der Werke, die ähnlich wie Lichtbildwerke geschaffen werden\n* Darstellungen wissenschaftlicher oder technischer Art wie Zeichnungen, Pläne, Karten, Skizzen, Tabellen und plastische Darstellungen.\n\nNach § 3 sind auch „Übersetzungen und andere Bearbeitungen“ von Werken geschützt, die persönliche geistige Schöpfungen des Bearbeiters sind“.\n\nSchließlich sind nach § 4 auch Sammelwerke und Datenbankwerke geschützt, was im Bereich Forschungsdaten durchaus relevant sein kann. Sammelbankwerke werden dabei definiert als „Sammlungen von Werken, Daten oder anderen unabhängigen Elementen, die aufgrund der Auswahl oder Anordnung der Elemente eine persönliche geistige Schöpfung sind“.\nBei einem „Datenbankwerk im Sinne des Gesetzes“ handelt es sich um ein „Sammelwerk, dessen Elemente systematisch oder methodisch angeordnet und einzeln mit Hilfe elektronischer Mittel oder auf andere Weise zugänglich sind“.\n\nWeitere relevante Schutzrechte können gewerbliche Schutzrechte wie Patente, Gebrauchsmuster, Sortenschutz [bei Pflanzenzüchtungen], Halbleiterschutz, Marken, geographische Herkunftsangaben, eingetragene Designs oder geschäftliche Bezeichnungen sein.',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 84,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/legal-and-ethics/sensitive-data-other/description',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/legal-and-ethics/sensitive-data-other/description',
#   'comment': '',
#   'locked': False,
#   'attribute': 165,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wenn ja, um welche nicht personenbezogenen sensiblen Daten handelt es sich?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [35],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [10],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/other/description',
#   'condition_uris': ['https://rdmorganiser.github.io/terms/conditions/other_sensitive_data'],
#   'optionset_uris': [],
#   'text_en': 'If yes, please describe the non-personal sensitive data used in the project.',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wenn ja, um welche nicht personenbezogenen sensiblen Daten handelt es sich?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 85,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/legal-and-ethics/sensitive-data-other/yesno',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/legal-and-ethics/sensitive-data-other/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 164,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Enthält dieser Datensatz nicht-personenbezogene sensible Daten?',
#   'help': 'Beispiele hierfür sind etwa Daten, die Betriebs- oder Geschäftsgeheimnisse oder Ortsangaben zu bedrohten Tier- oder Pflanzenarten enthalten.',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [35],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/other/yesno',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Does this dataset contain sensitive data other than personal data?',
#   'help_en': 'Examples are data that contain trade or business secrets or geoinformation on endangered species.',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Enthält dieser Datensatz nicht-personenbezogene sensible Daten?',
#   'help_de': 'Beispiele hierfür sind etwa Daten, die Betriebs- oder Geschäftsgeheimnisse oder Ortsangaben zu bedrohten Tier- oder Pflanzenarten enthalten.',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 86,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/legal-and-ethics/sensitive-data-personal_data_yesno/yesno',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/legal-and-ethics/sensitive-data-personal_data_yesno/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 154,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Enthält dieser Datensatz personenbezogene Daten?',
#   'help': '<p>Europäisches Recht kann Geltung haben.</p>\n<p>Das Bundesdatenschutzgesetz definiert personenbezogene Daten als „Einzelangaben über persönliche oder sachliche Verhältnisse einer bestimmten oder bestimmbaren natürlichen Person“ <a href="https://www.gesetze-im-internet.de/bdsg_2018/__3.html" target="_blank">(BDSG, §3 Abs. 1)</a></p>\n<p>Dabei wird von einer „bestimmten Person“ gesprochen, wenn eindeutig erkennbar ist, zu welcher Person die Daten gehören. Um eine „bestimmbare Person“ handelt es sich, wenn mittels Zusatzinformationen ermittelt werden kann, um welche Person es geht. (Vgl. Häder 2009, S. 7).</p>\n<p>Der Umgang mit solchen Daten ist gesetzlich geregelt. Mehr Informationen (zwar auf bestimmte Disziplinen / Datentypen fokussiert, aber übertragbar) zum Thema bieten bspw.:</p>\n<ul>\n<li>\n<p><a href="https://nbn-resolving.org/urn:nbn:de:0168-ssoar-419490" target="_blank">Michael Häder (2009): Der Datenschutz in den Sozialwissenschaften. RatSWD Working Paper No. 90.</a></p>\n</li>\n<li>\n<p><a href="http://www.gesis.org/fileadmin/upload/forschung/publikationen/gesis_reihen/gesis_methodenberichte/2012/TechnicalReport_2012-07.pdf" target="_blank">Uwe Jensen (2012): Leitlinien zum Management von Forschungsdaten. Sozialwissenschaftliche Umfragedaten. GESIS Technical Report 2012|07.</a> (v.a. S. 13ff.)</p>\n</li>\n<li>\n<p><a href="https://www.dfg.de/resource/blob/171632/383249f00d425a643bd8c120404bbff6/standards-sprachkorpora-data.pdf" target="_blank">Handreichung: Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora.</a> (v.a. Teil 1.1 und Teil 2.2)</p>\n</li>\n</ul>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [36],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/personal_data_yesno/yesno',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Does this dataset contain personal data?',
#   'help_en': 'European Data Protection Law may apply.\n\nThe handling of personal information is regulated by law. More information (in German only) can be found in the following publications:\n\n* <a href="https://nbn-resolving.org/urn:nbn:de:0168-ssoar-419490" target="_blank">Michael Häder (2009): Der Datenschutz in den Sozialwissenschaften. RatSWD Working Paper No. 90.</a>\n\n* <a href="http://www.gesis.org/fileadmin/upload/forschung/publikationen/gesis_reihen/gesis_methodenberichte/2012/TechnicalReport_2012-07.pdf" target="_blank">Uwe Jensen (2012): Leitlinien zum Management von Forschungsdaten. Sozialwissenschaftliche Umfragedaten. GESIS Technical Report 2012|07.</a> (esp. pp. 13 ff)\n\n* <a href="https://www.dfg.de/resource/blob/171632/383249f00d425a643bd8c120404bbff6/standards-sprachkorpora-data.pdf" target="_blank">Handreichung: Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora.</a> (esp. part 1.1 and part 2.2)',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Enthält dieser Datensatz personenbezogene Daten?',
#   'help_de': 'Europäisches Recht kann Geltung haben.\n\nDas Bundesdatenschutzgesetz definiert personenbezogene Daten als „Einzelangaben über persönliche oder sachliche Verhältnisse einer bestimmten oder bestimmbaren natürlichen Person“ <a href="https://www.gesetze-im-internet.de/bdsg_2018/__3.html" target="_blank">(BDSG, §3 Abs. 1)</a>\n\nDabei wird von einer „bestimmten Person“ gesprochen, wenn eindeutig erkennbar ist, zu welcher Person die Daten gehören. Um eine „bestimmbare Person“ handelt es sich, wenn mittels Zusatzinformationen ermittelt werden kann, um welche Person es geht. (Vgl. Häder 2009, S. 7).\n\nDer Umgang mit solchen Daten ist gesetzlich geregelt. Mehr Informationen (zwar auf bestimmte Disziplinen / Datentypen fokussiert, aber übertragbar) zum Thema bieten bspw.:\n\n* <a href="https://nbn-resolving.org/urn:nbn:de:0168-ssoar-419490" target="_blank">Michael Häder (2009): Der Datenschutz in den Sozialwissenschaften. RatSWD Working Paper No. 90.</a>\n\n* <a href="http://www.gesis.org/fileadmin/upload/forschung/publikationen/gesis_reihen/gesis_methodenberichte/2012/TechnicalReport_2012-07.pdf" target="_blank">Uwe Jensen (2012): Leitlinien zum Management von Forschungsdaten. Sozialwissenschaftliche Umfragedaten. GESIS Technical Report 2012|07.</a> (v.a. S. 13ff.)\n\n* <a href="https://www.dfg.de/resource/blob/171632/383249f00d425a643bd8c120404bbff6/standards-sprachkorpora-data.pdf" target="_blank">Handreichung: Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora.</a> (v.a. Teil 1.1 und Teil 2.2)',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 92,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing/metadata-dataset/creation_automatic',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/metadata-and-referencing/metadata-dataset/creation_automatic',
#   'comment': '',
#   'locked': False,
#   'attribute': 216,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Metadaten werden automatisch erhoben?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [39],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/metadata/creation_automatic',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Which metadata are collected automatically?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Metadaten werden automatisch erhoben?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 90,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing/metadata-dataset/creation_manual',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/metadata-and-referencing/metadata-dataset/creation_manual',
#   'comment': '',
#   'locked': False,
#   'attribute': 215,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Metadaten werden manuell erhoben?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [39],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/metadata/creation_manual',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Which metadata are collected manually?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Metadaten werden manuell erhoben?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 91,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing/metadata-dataset/creation_semi_automatic',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/metadata-and-referencing/metadata-dataset/creation_semi_automatic',
#   'comment': '',
#   'locked': False,
#   'attribute': 214,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Metadaten werden semi-automatisch erhoben?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [39],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/metadata/creation_semi_automatic',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Which metadata are collected semi-automatically?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Metadaten werden semi-automatisch erhoben?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 87,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing/structure-granularity-and-referencing-pids/system',
# ...
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wie wird die Identität von Personen, die auf die Daten zugreifen, verifiziert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/access_authentication',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'How will the identity of the person accessing the data will be ascertained?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wie wird die Identität von Personen, die auf die Daten zugreifen, verifiziert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 405,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/certification',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/certification',
#   'comment': '',
#   'locked': False,
#   'attribute': 190,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': '<p>Handelt es sich dabei um ein zertifiziertes Repositorium oder Datenzentrum (z. B. durch das Data Seal of Approval, nestor-Siegel oder ISO 16363)?\n(Wurden mehrere Langzeitarchivierungsoptionen ausgewählt, kann die Frage bejaht werden, wenn dies auf mindestens eine der Optionen zutrifft).</p>',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/certification',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Is the repository or data centre chosen certified (e.g. Data Seal of Approval, nestor Seal or ISO 16363)?\n(If the dataset is archived at several places, you may answer this question with yes, if this applies to at least one of these.)',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Handelt es sich dabei um ein zertifiziertes Repositorium oder Datenzentrum (z. B. durch das Data Seal of Approval, nestor-Siegel oder ISO 16363)?\n(Wurden mehrere Langzeitarchivierungsoptionen ausgewählt, kann die Frage bejaht werden, wenn dies auf mindestens eine der Optionen zutrifft).',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 401,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/data_archiving_date',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/data_archiving_date',
#   'comment': '',
#   'locked': False,
#   'attribute': 189,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'date',
#   'value_type': 'datetime',
#   'unit': '',
#   'width': None,
#   'text': 'Wann werden die Daten archiviert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/data_archiving_date',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'By when will the data be archived?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wann werden die Daten archiviert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 408,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/duration',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/duration',
#   'comment': '',
#   'locked': False,
#   'attribute': 188,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wie lange müssen die Daten aufbewahrt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/duration',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'How long will the data be stored?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wie lange müssen die Daten aufbewahrt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 403,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/embargo_period',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/embargo_period',
#   'comment': '',
#   'locked': False,
#   'attribute': 185,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Sollen die Daten erst nach Ablauf einer Sperrfrist zugänglich gemacht werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/embargo_period',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Shall there be an embargo period before the data are made available?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Sollen die Daten erst nach Ablauf einer Sperrfrist zugänglich gemacht werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 404,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/repository_arrangements',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/repository_arrangements',
#   'comment': '',
#   'locked': False,
#   'attribute': 182,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Wurde mit dem Repositorium oder Datenzentrum bereits angemessene Archivierungslösungen besprochen?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/repository_arrangements',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Have you explored appropriate arrangements with the identified repository?',
#   'help_en': '(original question from Horizon 2020 FAIR Data Management Plan)',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wurde mit dem Repositorium oder Datenzentrum bereits angemessene Archivierungslösungen besprochen?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 407,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/reuse_duration',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/reuse_duration',
#   'comment': 'Original H2020 question',
#   'locked': False,
#   'attribute': 178,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'text',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wie lang sollen die Daten nach Projektende (nach)nutzbar sein?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/reuse_duration',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'How long is it intended that the data remains re-usable.',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wie lang sollen die Daten nach Projektende (nach)nutzbar sein?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 410,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/long-term-preservation-datasets/yesno',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/long-term-preservation-datasets/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 176,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'yesno',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Muss dieser Datensatz langfristig aufbewahrt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [151],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/preservation/yesno',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Does this dataset have to preserved for the long-term?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Muss dieser Datensatz langfristig aufbewahrt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 416,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/storage_project-storage/type',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/storage_project-storage/type',
#   'comment': '',
#   'locked': False,
#   'attribute': 136,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'textarea',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wo wird der Datensatz während des Projektes gespeichert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [154],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/type',
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Where is the dataset stored during the project?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wo wird der Datensatz während des Projektes gespeichert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 415,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/storage_project-usage/infrastructure',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/storage_project-usage/infrastructure',
#   'comment': '',
#   'locked': False,
#   'attribute': 128,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [153],
#   'questionsets': [],
#   'optionsets': [30],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_infrastructure',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/infrastructure_resources'],
#   'text_en': 'To what extent will infrastructure resources be required (e.g. CPU hours, bandwidth, storage space... etc.).',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 414,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/storage_project-usage/support',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/storage_project-usage/support',
#   'comment': '',
#   'locked': False,
#   'attribute': 127,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [153],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_support',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Are there actual or potential usage scenarios that could benefit from support by a data management or IT expert, or that even require such support?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''}]

# %%
client.list_questions(widget_type='radio')
# Out:
# [{'id': 479,
#   'model': 'questions.question',
#   'uri': 'https://github.com/RDA-DMP-Common/questions/ethics_exists',
#   'uri_prefix': 'https://github.com/RDA-DMP-Common',
#   'uri_path': 'ethics_exists',
#   'comment': '',
#   'locked': False,
#   'attribute': None,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': '',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [],
#   'questionsets': [],
#   'optionsets': [],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': True},
#   'read_only': False,
#   'condition_uris': [],
#   'optionset_uris': [],
#   'text_en': 'Are there any ethical issues?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': '',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 108,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/content-classification/data-existing_data/origin',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/content-classification/data-existing_data/origin',
#   'comment': '',
#   'locked': False,
#   'attribute': 199,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Wird der Datensatz selbst erzeugt oder nachgenutzt?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [48],
#   'questionsets': [],
#   'optionsets': [58],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/origin',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_origin_options'],
#   'text_en': 'Is the dataset being created or re-used?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wird der Datensatz selbst erzeugt oder nachgenutzt?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 94,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/data-sharing-and-re-use-publication/yesno',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/data-sharing-and-re-use-publication/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 144,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [40],
#   'questionsets': [],
#   'optionsets': [55],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sharing/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_sharing_options'],
#   'text_en': 'Will this dataset be published or shared?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 100,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/scenarios-usage/infrastructure',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/scenarios-usage/infrastructure',
#   'comment': '',
#   'locked': False,
#   'attribute': 128,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [43],
#   'questionsets': [],
#   'optionsets': [30],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_infrastructure',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/infrastructure_resources'],
#   'text_en': 'To what extent will infrastructure resources be required (e.g. CPU hours, bandwidth, storage space... etc.).',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 99,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/data-usage/scenarios-usage/support',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/data-usage/scenarios-usage/support',
#   'comment': '',
#   'locked': False,
#   'attribute': 127,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [43],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_support',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Are there actual or potential usage scenarios that could benefit from support by a data management or IT expert, or that even require such support?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 87,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/metadata-and-referencing/structure-granularity-and-referencing-pids/system',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/metadata-and-referencing/structure-granularity-and-referencing-pids/system',
#   'comment': '',
#   'locked': False,
#   'attribute': 194,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welches System von persistenten Identifikatoren soll genutzt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [37],
#   'questionsets': [],
#   'optionsets': [23],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/pids/system',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/pid_types'],
#   'text_en': 'Which system of persistent identifiers shall be used?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welches System von persistenten Identifikatoren soll genutzt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 101,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/technical-classification/data-versioning/tool',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/technical-classification/data-versioning/tool',
#   'comment': '',
#   'locked': False,
#   'attribute': 123,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Technologie bzw. welches Tool wird zur Versionierung verwendet?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [44],
#   'questionsets': [],
#   'optionsets': [5],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/versioning_tool',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/software_versioning_technology_options'],
#   'text_en': 'Which technology or tool is used for versioning?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Technologie bzw. welches Tool wird zur Versionierung verwendet?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 105,
#   'model': 'questions.question',
#   'uri': 'https://rdmo.fh-potsdam.de/terms/questions/fhpshort/technical-classification/data-volume/volume',
#   'uri_prefix': 'https://rdmo.fh-potsdam.de/terms',
#   'uri_path': 'fhpshort/technical-classification/data-volume/volume',
#   'comment': '',
#   'locked': False,
#   'attribute': 141,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'float',
#   'unit': '',
#   'width': None,
#   'text': 'Was ist die tatsächliche oder erwartete Größe des Datensatzes?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [47],
#   'questionsets': [],
#   'optionsets': [53],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/size/volume',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_size_options'],
#   'text_en': 'What is the actual or expected size of the dataset?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Was ist die tatsächliche oder erwartete Größe des Datensatzes?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 72,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection/dataset-dataset/origin',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection/dataset-dataset/origin',
#   'comment': '',
#   'locked': False,
#   'attribute': 199,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Werden die Daten selbst erzeugt oder nachgenutzt?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [30],
#   'questionsets': [],
#   'optionsets': [58],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/origin',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_origin_options'],
#   'text_en': 'Is the data being created or re-used?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Werden die Daten selbst erzeugt oder nachgenutzt?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 68,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection/dataset-format_size/volume',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection/dataset-format_size/volume',
#   'comment': '',
#   'locked': False,
#   'attribute': 141,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'float',
#   'unit': '',
#   'width': None,
#   'text': 'Was ist die tatsächliche oder erwartete Größe des Datensatzes?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [29],
#   'questionsets': [],
#   'optionsets': [53],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/size/volume',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_size_options'],
#   'text_en': 'What is the actual or expected size of the dataset?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Was ist die tatsächliche oder erwartete Größe des Datensatzes?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 62,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection/process-structure/naming_policy',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection/process-structure/naming_policy',
#   'comment': '',
#   'locked': False,
#   'attribute': 138,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es eine projektinterne Richtlinie zur Benennung der Daten? Wenn ja, bitte skizzieren Sie sie kurz und verlinken Sie ggf. zu einer ausführlicheren Dokumentation.',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [27],
#   'questionsets': [],
#   'optionsets': [2],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/naming_policy',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_no_not_yet'],
#   'text_en': 'Is there a internal project guideline for naming the data? If so, please briefly outline the naming conventions and, if necessary, link to the documentation.',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es eine projektinterne Richtlinie zur Benennung der Daten? Wenn ja, bitte skizzieren Sie sie kurz und verlinken Sie ggf. zu einer ausführlicheren Dokumentation.',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 63,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection/process-structure/organisation_policy',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection/process-structure/organisation_policy',
#   'comment': '',
#   'locked': False,
#   'attribute': 137,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es projektinterne Richtlinien zur einheitlichen Organisation der Daten? Wenn ja, wo sind diese festgehalten?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [27],
#   'questionsets': [],
#   'optionsets': [2],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/organisation_policy',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_no_not_yet'],
#   'text_en': 'Are there internal project guidelines for a consistent organisation of the data? If so, where they are documented?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es projektinterne Richtlinien zur einheitlichen Organisation der Daten? Wenn ja, wo sind diese festgehalten?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 65,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/collection/process-versioning/tool',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/collection/process-versioning/tool',
#   'comment': '',
#   'locked': False,
#   'attribute': 123,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welche Technologie bzw. welches Tool wird zur Versionierung verwendet?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [28],
#   'questionsets': [],
#   'optionsets': [5],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/versioning_tool',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/software_versioning_technology_options'],
#   'text_en': 'Which technology or tool is used for versioning?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welche Technologie bzw. welches Tool wird zur Versionierung verwendet?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 55,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/ethics_legal/ethics-personal_data/anonymization',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/ethics_legal/ethics-personal_data/anonymization',
#   'comment': '',
#   'locked': False,
#   'attribute': 162,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Werden die Daten anonymisiert oder pseudonymisiert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [25],
#   'questionsets': [],
#   'optionsets': [65],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/personal_data/anonymization',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_anonymisation'],
#   'text_en': 'Will the data be anonymised or pseudonymised?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Werden die Daten anonymisiert oder pseudonymisiert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 54,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/ethics_legal/ethics-personal_data/extent',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/ethics_legal/ethics-personal_data/extent',
#   'comment': '',
#   'locked': False,
#   'attribute': 160,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang wird die "informierte Einwilligung" der Betroffenen eingeholt?',
#   'help': '<p>Grundsätzlich gilt, dass eine Erhebung, Verarbeitung, Archivierung und Veröffentlichung personenbezogener Daten nur zulässig ist, wenn eine entsprechende „informierte Einwilligung“ der Betroffenen vorliegt. Nur in ganz wenigen,\n            jeweils in den Datenschutzgesetzen definierten Ausnahmefällen wird diese nicht benötigt (vgl., auch für mehr Information, <a\n            href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen Aspekten bei der Handhabung von\n            Sprachkorpora</a>, S. 6).</p>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [25],
#   'questionsets': [],
#   'optionsets': [31],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/personal_data/consent/extent',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/informed_consent_options'],
#   'text_en': 'To what extent is the "informed consent" obtained from the persons concerned?',
#   'help_en': 'Basically, the collection, processing, archiving and publication of personal data is only admissible, when the “informed consent” of the person in question has been obtained. There are only very few cases in which this is not the case\n\t\t\t(see, also for more information: <a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen\n\t\t\tAspekten bei der Handhabung von Sprachkorpora</a>, p. 6).',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang wird die "informierte Einwilligung" der Betroffenen eingeholt?',
#   'help_de': 'Grundsätzlich gilt, dass eine Erhebung, Verarbeitung, Archivierung und Veröffentlichung personenbezogener Daten nur zulässig ist, wenn eine entsprechende „informierte Einwilligung“ der Betroffenen vorliegt. Nur in ganz wenigen,\n\t\t\tjeweils in den Datenschutzgesetzen definierten Ausnahmefällen wird diese nicht benötigt (vgl., auch für mehr Information, <a\n\t\t\thref="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen Aspekten bei der Handhabung von\n\t\t\tSprachkorpora</a>, S. 6).',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 50,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/ethics_legal/ipr-ipr/owner',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/ethics_legal/ipr-ipr/owner',
#   'comment': '',
#   'locked': False,
#   'attribute': 223,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Wurde der/die Rechteinhaber/in recherchiert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [24],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/ipr/owner/name',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Was investigated who the rights owner is?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wurde der/die Rechteinhaber/in recherchiert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 24,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/responsibilities_resources/resources-resources/infrastructure',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/responsibilities_resources/resources-resources/infrastructure',
#   'comment': '',
#   'locked': False,
#   'attribute': 128,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [15],
#   'questionsets': [],
#   'optionsets': [30],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_infrastructure',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/infrastructure_resources'],
#   'text_en': 'To what extent will infrastructure resources be required (e.g. CPU hours, bandwidth, storage space... etc.).',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 23,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/responsibilities_resources/resources-resources/support',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/responsibilities_resources/resources-resources/support',
#   'comment': '',
#   'locked': False,
#   'attribute': 127,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [15],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_support',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Are there actual or potential usage scenarios that could benefit from support by a data management or IT expert, or that even require such support?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 31,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/sharing/sharing-pid/system',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/sharing/sharing-pid/system',
#   'comment': '',
#   'locked': False,
#   'attribute': 194,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Welches System von persistenten Identifikatoren soll genutzt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [18],
#   'questionsets': [],
#   'optionsets': [23],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/pids/system',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/pid_types'],
#   'text_en': 'Which system of persistent identifiers shall be used?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welches System von persistenten Identifikatoren soll genutzt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 36,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/dcc/sharing/sharing-sharing/yesno',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'dcc/sharing/sharing-sharing/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 144,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [19],
#   'questionsets': [],
#   'optionsets': [55],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sharing/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_sharing_options'],
#   'text_en': 'Will this dataset be published or shared?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 21,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/data_description/data_content/ds_reuse',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/data_description/data_content/ds_reuse',
#   'comment': '',
#   'locked': False,
#   'attribute': 199,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Werden existierende Daten wiederverwendet?',
#   'help': '<p>Damit sind sowohl eigene Daten aus vorherigen Projekten als auch öffentlich oder kommerziell verfügbare Daten gemeint. Auch die Nachnutzung von Daten anderer Forschender sollte hier erwähnt werden. Wenn Daten verwendet werden, die nicht im Rahmen dieses Projekts entstanden sind, geben Sie bitte den Kontext an, aus dem die Daten stammen, und fügen Sie möglichst eine zitierfähige Quelle hinzu (z. B. über eine DOI). Andernfalls empfiehlt sich ein Hinweis, dass nach eigener Recherche keine geeigneten Daten zur Verfügung stehen.</p>\n<details>\n<summary style="color:blue; cursor:pointer;">Erläuterung:</summary>\nManche Daten können im Prinzip jederzeit neu erstellt werden. Beispiele hierfür sind etwa naturwissenschaftliche Experimentdaten oder auch Digitalisate analoger Objekte (sofern die Originale vorhanden sind). Der Aufwand und die Kosten hierfür können durchaus beträchtlich sein. Im Hinblick auf die Frage der Notwendigkeit einer späteren Archivierung sollte in diesen Fällen der Aufwand einer erneuten Erstellung gegen den Aufwand der Archivierung abgewogen werden.\n\nAndere Daten lassen sich hingegen per se nicht erneut erheben. Dies ist beispielsweise bei jeglicher Art von episodischen Beobachtungen der Fall, da diese ein bestimmtes Phänomen zu einem bestimmten Zeitpunkt und/oder an einem bestimmten Ort abbilden und somit in der Regel nicht wiederholbar sind. Ihr Wert für die Nachnutzung durch andere sowie der Verlust bei einer nicht erfolgten oder misslungenen Archivierung sind ungleich höher als bei reproduzierbaren Daten.\n</details>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [13],
#   'questionsets': [],
#   'optionsets': [41],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/origin',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dfg_reuse'],
#   'text_en': 'Are existing data being reused?',
#   'help_en': 'This refers to your own data from previous projects, as well as publicly or commercially available data. Re-using other scientists\' data should also be mentioned here. Data re-used from other researchers should also be mentioned here. If you use data that was not generated as part of this project, please state where the data originates from and, if possible, add a citable source (e.g. via a DOI). Otherwise, it is advisable to indicate that no suitable data was found during your own research.\n\n<details>\n<summary style="color:blue; cursor:pointer;">Explanation:</summary>\n\nIn principle, some data can be re-created at any time. Examples include scientific experiment data and digital copies of analogue objects (provided the originals are available). However, the effort and costs involved can be considerable. Regarding the necessity of subsequent archiving, the cost of re-creation should be weighed against the archiving cost.\n\nOther data, on the other hand, cannot be collected again as such. This applies to any kind of episodic observation, as these depict a specific phenomenon at a specific time and/or in a specific place, and are therefore generally not repeatable. The value of such data for subsequent use by others, as well as the consequences of unsuccessful archiving, is incomparably higher than that of reproducible data.\n</details>',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Werden existierende Daten wiederverwendet?',
#   'help_de': 'Damit sind sowohl eigene Daten aus vorherigen Projekten als auch öffentlich oder kommerziell verfügbare Daten gemeint. Auch die Nachnutzung von Daten anderer Forschender sollte hier erwähnt werden. Wenn Daten verwendet werden, die nicht im Rahmen dieses Projekts entstanden sind, geben Sie bitte den Kontext an, aus dem die Daten stammen, und fügen Sie möglichst eine zitierfähige Quelle hinzu (z. B. über eine DOI). Andernfalls empfiehlt sich ein Hinweis, dass nach eigener Recherche keine geeigneten Daten zur Verfügung stehen.\n\n<details>\n<summary style="color:blue; cursor:pointer;">Erläuterung:</summary>\nManche Daten können im Prinzip jederzeit neu erstellt werden. Beispiele hierfür sind etwa naturwissenschaftliche Experimentdaten oder auch Digitalisate analoger Objekte (sofern die Originale vorhanden sind). Der Aufwand und die Kosten hierfür können durchaus beträchtlich sein. Im Hinblick auf die Frage der Notwendigkeit einer späteren Archivierung sollte in diesen Fällen der Aufwand einer erneuten Erstellung gegen den Aufwand der Archivierung abgewogen werden.\n\nAndere Daten lassen sich hingegen per se nicht erneut erheben. Dies ist beispielsweise bei jeglicher Art von episodischen Beobachtungen der Fall, da diese ein bestimmtes Phänomen zu einem bestimmten Zeitpunkt und/oder an einem bestimmten Ort abbilden und somit in der Regel nicht wiederholbar sind. Ihr Wert für die Nachnutzung durch andere sowie der Verlust bei einer nicht erfolgten oder misslungenen Archivierung sind ungleich höher als bei reproduzierbaren Daten.\n</details>',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 18,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/data_description/technical_description/ds_size',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/data_description/technical_description/ds_size',
#   'comment': '',
#   'locked': False,
#   'attribute': 141,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Welches Datenvolumen ist für den Datensatz zu erwarten?',
#   'help': 'Geben Sie bitte außerdem die Maßeinheit an, z. B. "10 GB".',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [12],
#   'questionsets': [],
#   'optionsets': [48],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/size/volume',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dfg_dataset_size_options'],
#   'text_en': 'What data volume is expected for the data set?',
#   'help_en': 'Please also specify the unit of measurement, e.g. "10GB".',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Welches Datenvolumen ist für den Datensatz zu erwarten?',
#   'help_de': 'Geben Sie bitte außerdem die Maßeinheit an, z. B. "10 GB".',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 5,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/DFG-Checkliste/exchange_access/reuse/reuse_when',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'DFG-Checkliste/exchange_access/reuse/reuse_when',
#   'comment': '',
#   'locked': False,
#   'attribute': 243,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Wann ist dieser Datensatz für Dritte nutzbar?',
#   'help': '<p>Entsprechend den <i><a href="https://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/forschungsdaten/leitlinien_forschungsdaten.pdf" target="_blank">DFG–Leitlinien zum Forschungsdatenmanagement</a></i> sollten Forschungsdaten wenn möglich zeitnah verfügbar gemacht werden.Im besten Fall folgen sie dabei den <i><a href="https://force11.org/info/guiding-principles-for-findable-accessible-interoperable-and-re-usable-data-publishing-version-b1-0/" target="_blank">FAIR-Prinzipien</a></i>.</p>\n<p>Die Bedeutung der Datenpublikation wird durch die\n<i><a href="https://wissenschaftliche-integritaet.de/kodex/herstellung-von-offentlichem-zugang-zu-forschungsergebnissen/" target="_blank">Leitlinie 13 des Kodex zur Guten Wissenschaftlichen Praxis</a></i> noch einmal unterstrichen. Hier wird auf die disziplinspezifischen Gepflogenheiten hingewiesen.</p>\n<details>\n<summary style="color:blue; cursor:pointer;">Empfohlene Repositorien</summary>\n\nFür die Publikation von Forschungsdaten wird die Nutzung  fachspezifische Repositorien empfohlen. Empfehlenswerte Verzeichnisse hierfür sind  <i><a href="https://www.re3data.org/" target="_blank">re3data.org</a></i> und <i><a href="https://fairsharing.org/" target="_blank">FAIRsharing.org</a></i>.\n\nFalls kein geeignetes fachspezifisches Repositorium existiert, erkundigen Sie sich, ob Ihre Einrichtung ein institutionelles Repositorium betreibt. Eine weitere Alternative ist <i><a href="https://zenodo.org/" target="_blank">Zenodo</a></i>.\n</details>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [4],
#   'questionsets': [],
#   'optionsets': [37],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/data_publication_date',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dfg_using_when'],
#   'text_en': 'When can third parties use this data set?',
#   'help_en': 'According to the <i><a href="https://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/forschungsdaten/leitlinien_forschungsdaten.pdf" target="_blank">DFG Guidelines for Research Data Management</a ></i>, research data should be made available as soon as possible. Ideally, it should adhere to the <i><a href="https://force11.org/info/guiding-principles-for-findable-accessible-interoperable-and-re-usable-data-publishing-version-b1-0/" target="_blank">FAIR principles</a></i>.\n\n<i><a href="https://wissenschaftliche-integritaet.de/en/code-of-conduct/providing-public-access-to-research-results/" target="_blank">Guideline 13 of the Code of Good Scientific Practice</a ></i> once again emphasises the importance of data publication. Here, reference is made to discipline-specific practices.\n\n<details>\n<summary style="color:blue; cursor:pointer;">Recommended repositories</summary>\n\nSubject-specific repositories are recommended for the publication of research data. Recommended directories for this purpose are <i><a href="https://www.re3data.org/" target="_blank">re3data.org</a></i> and <i><a href="https://fairsharing.org/" target="_blank">FAIRsharing.org</a></i>.\n\nIf there is no suitable subject-specific repository, check whether your institution operates an institutional repository. Another alternative is <i><a href="https://zenodo.org/" target="_blank">Zenodo</a></i>.\n</details>',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wann ist dieser Datensatz für Dritte nutzbar?',
#   'help_de': 'Entsprechend den <i><a href="https://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/forschungsdaten/leitlinien_forschungsdaten.pdf" target="_blank">DFG–Leitlinien zum Forschungsdatenmanagement</a></i> sollten Forschungsdaten wenn möglich zeitnah verfügbar gemacht werden.Im besten Fall folgen sie dabei den <i><a href="https://force11.org/info/guiding-principles-for-findable-accessible-interoperable-and-re-usable-data-publishing-version-b1-0/" target="_blank">FAIR-Prinzipien</a></i>.\n\nDie Bedeutung der Datenpublikation wird durch die\n<i><a href="https://wissenschaftliche-integritaet.de/kodex/herstellung-von-offentlichem-zugang-zu-forschungsergebnissen/" target="_blank">Leitlinie 13 des Kodex zur Guten Wissenschaftlichen Praxis</a></i> noch einmal unterstrichen. Hier wird auf die disziplinspezifischen Gepflogenheiten hingewiesen.\n\n<details>\n<summary style="color:blue; cursor:pointer;">Empfohlene Repositorien</summary>\n\nFür die Publikation von Forschungsdaten wird die Nutzung  fachspezifische Repositorien empfohlen. Empfehlenswerte Verzeichnisse hierfür sind  <i><a href="https://www.re3data.org/" target="_blank">re3data.org</a></i> und <i><a href="https://fairsharing.org/" target="_blank">FAIRsharing.org</a></i>.\n\nFalls kein geeignetes fachspezifisches Repositorium existiert, erkundigen Sie sich, ob Ihre Einrichtung ein institutionelles Repositorium betreibt. Eine weitere Alternative ist <i><a href="https://zenodo.org/" target="_blank">Zenodo</a></i>.\n</details>',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 111,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/fhpshort/general/other-requirements-yesno/yesno',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'fhpshort/general/other-requirements-yesno/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 305,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es von weiteren Seiten (z. B. von der Fachcommunity) Anforderungen an das Datenmanagement, die beachtet werden müssen?',
#   'help': '<p>Beispiele für fachspezifische Empfehlungen und Richtlinien sind:</p>\n<ul>\n<li><a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/richtlinien_forschungsdaten_biodiversitaetsforschung.pdf" target="_blank">Richtlinien zum Umgang mit Forschungsdaten in der Biodiversitätsforschung</a></li>\n<li>Empfehlungen zur <a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/richtlinien_forschungsdaten_bildungsforschung.pdf" target="_blank">Bereitstellung und Nutzung quantitativer Daten in der Bildungsforschung</a></li>\n<li><a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/foerderkriterien_editionen_literaturwissenschaft.pdf" target="_blank">Förderkriterien für wissenschaftliche Editionen in der Literaturwissenschaft</a></li>\n<li>Empfehlungen zu</li>\n<li><a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_sprachkorpora.pdf" target="_blank">datentechnischen Standards und Tools</a> sowie zu</li>\n<li><a href="https://www.dfg.de/resource/blob/171632/383249f00d425a643bd8c120404bbff6/standards-sprachkorpora-data.pdf" target="_blank">rechtlichen Fragen</a> bei der Erhebung von Sprachkorpora</li>\n</ul>',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [51],
#   'questionsets': [],
#   'optionsets': [25],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/additional_rdm_policy/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/other_requirements_options'],
#   'text_en': 'Are there requirements regarding the data management from other parties  (e.g. the scholarly/scientific community)?',
#   'help_en': 'Examples of discipline-specific requirements are:\n\n- <a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/guidelines_biodiversity_research.pdf" target="_blank">Guidelines on the Handling of Research Data in Biodiversity Research (German only)</a>\n- <a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/richtlinien_forschungsdaten_bildungsforschung.pdf" target="_blank">Guidelines for the provision and use of quantitative data in education research (German only)</a>\n- <a href="http://www.dfg.de/download/pdf/foerderung/antragstellung/forschungsdaten/foerderkriterien_editionen_literaturwissenschaft.pdf" target="_blank">Elegibility criteria for funding for scholarly editions in the literary studies (German only)</a>\n- Recommendations on <a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_sprachkorpora.pdf" target="_blank">data standards and tools</a> as well as <a href="https://www.dfg.de/resource/blob/171632/383249f00d425a643bd8c120404bbff6/standards-sprachkorpora-data.pdf" target="_blank">legal aspects</a> associated with language corpora (German only)',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es von weiteren Seiten (z. B. von der Fachcommunity) Anforderungen an das Datenmanagement, die beachtet werden müssen?',
# ...
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [150],
#   'questionsets': [],
#   'optionsets': [2],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/naming_policy',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_no_not_yet'],
#   'text_en': 'Is there a internal project guideline for naming the data? If so, please briefly outline the naming conventions and, if necessary, link to the documentation.',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es eine projektinterne Richtlinie zur Benennung der Daten? Wenn ja, bitte skizzieren Sie sie kurz und verlinken Sie ggf. zu einer ausführlicheren Dokumentation.',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 399,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/data-usage/data-sharing-and-re-use-interoperability/organisation_policy',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/data-usage/data-sharing-and-re-use-interoperability/organisation_policy',
#   'comment': '',
#   'locked': False,
#   'attribute': 137,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es projektinterne Richtlinien zur einheitlichen Organisation der Daten? Wenn ja, wo sind diese festgehalten?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [150],
#   'questionsets': [],
#   'optionsets': [2],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/storage/organisation_policy',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_no_not_yet'],
#   'text_en': 'Are there internal project guidelines for a consistent organisation of the data? If so, where they are documented?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es projektinterne Richtlinien zur einheitlichen Organisation der Daten? Wenn ja, wo sind diese festgehalten?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 397,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/data-usage/data-sharing-and-re-use-publication/yesno',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/data-usage/data-sharing-and-re-use-publication/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 144,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [149],
#   'questionsets': [],
#   'optionsets': [55],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sharing/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_sharing_options'],
#   'text_en': 'Will this dataset be published or shared?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Soll dieser Datensatz veröffentlicht oder geteilt werden?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 418,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics/intellectual-property-rights-dataset/owner',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics/intellectual-property-rights-dataset/owner',
#   'comment': '',
#   'locked': False,
#   'attribute': 223,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Wurde der/die Rechteinhaber/in recherchiert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [155],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/ipr/owner/name',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Was investigated who the rights owner is?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wurde der/die Rechteinhaber/in recherchiert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 428,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics/sensitive-data-official_approval/ethics_committee',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics/sensitive-data-official_approval/ethics_committee',
#   'comment': '',
#   'locked': False,
#   'attribute': 100,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'option',
#   'unit': '',
#   'width': None,
#   'text': 'Wurde das Forschungsvorhaben von einer Ethikkommission begutachtet?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [158],
#   'questionsets': [],
#   'optionsets': [34],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/legal_aspects/official_approval/ethics_committee',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/ethics_committee_approval_options'],
#   'text_en': 'Has the project been approved by a research ethics committee?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wurde das Forschungsvorhaben von einer Ethikkommission begutachtet?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 427,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics/sensitive-data-official_approval/yesno',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics/sensitive-data-official_approval/yesno',
#   'comment': '',
#   'locked': False,
#   'attribute': 96,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'boolean',
#   'unit': '',
#   'width': None,
#   'text': 'Wird für das Forschungsvorhaben eine offizielle Genehmigung benötigt?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [158],
#   'questionsets': [],
#   'optionsets': [33],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/legal_aspects/official_approval/statutatory_approval/yesno',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/ethics_permit_options'],
#   'text_en': 'Is a statutatory approval / permit needed for the research?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Wird für das Forschungsvorhaben eine offizielle Genehmigung benötigt?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 434,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics/sensitive-data-personal_data/anonymization',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics/sensitive-data-personal_data/anonymization',
#   'comment': '',
#   'locked': False,
#   'attribute': 162,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Werden die Daten anonymisiert oder pseudonymisiert?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [159],
#   'questionsets': [],
#   'optionsets': [65],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/personal_data/anonymization',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/dataset_anonymisation'],
#   'text_en': 'Will the data be anonymised or pseudonymised?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Werden die Daten anonymisiert oder pseudonymisiert?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 433,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/legal-and-ethics/sensitive-data-personal_data/extent',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/legal-and-ethics/sensitive-data-personal_data/extent',
#   'comment': '',
#   'locked': False,
#   'attribute': 160,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang wird die "informierte Einwilligung" der Betroffenen eingeholt?',
#   'help': 'Grundsätzlich gilt, dass eine Erhebung, Verarbeitung, Archivierung und Veröffentlichung personenbezogener Daten nur zulässig ist, wenn eine entsprechende „informierte Einwilligung“ der Betroffenen vorliegt. Nur in ganz wenigen, jeweils in den Datenschutzgesetzen definierten Ausnahmefällen wird diese nicht benötigt (vgl., auch für mehr Information, <a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora</a>, S. 6).',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [159],
#   'questionsets': [],
#   'optionsets': [31],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/sensitive_data/personal_data/consent/extent',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/informed_consent_options'],
#   'text_en': 'To what extent is the "informed consent" obtained from the persons concerned?',
#   'help_en': 'Basically, the collection, processing, archiving and publication of personal data is only admissible, when the “informed consent” of the person in question has been obtained. There are only very few cases in which this is not the case (see, also for more information: <a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora</a>, p. 6).',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang wird die "informierte Einwilligung" der Betroffenen eingeholt?',
#   'help_de': 'Grundsätzlich gilt, dass eine Erhebung, Verarbeitung, Archivierung und Veröffentlichung personenbezogener Daten nur zulässig ist, wenn eine entsprechende „informierte Einwilligung“ der Betroffenen vorliegt. Nur in ganz wenigen, jeweils in den Datenschutzgesetzen definierten Ausnahmefällen wird diese nicht benötigt (vgl., auch für mehr Information, <a href="http://www.dfg.de/download/pdf/foerderung/grundlagen_dfg_foerderung/informationen_fachwissenschaften/geisteswissenschaften/standards_recht.pdf" target="_blank">Informationen zu rechtlichen Aspekten bei der Handhabung von Sprachkorpora</a>, S. 6).',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 415,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/storage_project-usage/infrastructure',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/storage_project-usage/infrastructure',
#   'comment': '',
#   'locked': False,
#   'attribute': 128,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [153],
#   'questionsets': [],
#   'optionsets': [30],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_infrastructure',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/infrastructure_resources'],
#   'text_en': 'To what extent will infrastructure resources be required (e.g. CPU hours, bandwidth, storage space... etc.).',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'In welchem Umfang werden Infrastrukturressourcen benötigt (CPU-Stunden, Bandbreite, Speicherplatz etc.)?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''},
#  {'id': 414,
#   'model': 'questions.question',
#   'uri': 'https://rdmorganiser.github.io/terms/questions/snf/storage-and-long-term-preservation/storage_project-usage/support',
#   'uri_prefix': 'https://rdmorganiser.github.io/terms',
#   'uri_path': 'snf/storage-and-long-term-preservation/storage_project-usage/support',
#   'comment': '',
#   'locked': False,
#   'attribute': 127,
#   'is_collection': False,
#   'is_optional': False,
#   'maximum': None,
#   'minimum': None,
#   'step': None,
#   'default_option': None,
#   'default_external_id': '',
#   'widget_type': 'radio',
#   'value_type': 'text',
#   'unit': '',
#   'width': None,
#   'text': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help': '',
#   'default_text': '',
#   'verbose_name': '',
#   'pages': [153],
#   'questionsets': [],
#   'optionsets': [1],
#   'conditions': [],
#   'editors': [],
#   'warning': {'missing_languages': False},
#   'read_only': False,
#   'attribute_uri': 'https://rdmorganiser.github.io/terms/domain/project/dataset/usage_support',
#   'condition_uris': [],
#   'optionset_uris': ['https://rdmorganiser.github.io/terms/options/yes_with_text_no'],
#   'text_en': 'Are there actual or potential usage scenarios that could benefit from support by a data management or IT expert, or that even require such support?',
#   'help_en': '',
#   'default_text_en': '',
#   'verbose_name_en': '',
#   'text_de': 'Gibt es beabsichtigte (ggf. auch potentielle) Nutzungsszenarien, für die die Unterstützung durch Datenmanagement- oder IT-ExpertInnen sinnvoll oder notwendig ist?',
#   'help_de': '',
#   'default_text_de': '',
#   'verbose_name_de': ''}]
