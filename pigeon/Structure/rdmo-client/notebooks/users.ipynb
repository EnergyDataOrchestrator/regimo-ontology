# %%
from rdmo_client import Client

BASE_URL = 'http://localhost:8484'
AUTH = ('rdmo', 'rdmo')
TOKEN = '106cac9b5072b7dcfce4c96a2f52cb302b79fb20'
URI_PREFIX = 'https://rdmorganiser.github.io/terms/'

client = Client(BASE_URL, auth=AUTH)

# %%
client.list_users()
# Out:
# [{'id': 1,
#   'groups': [],
#   'role': {'id': 3,
#    'member': [{'id': 1, 'name': 'example.com', 'domain': 'example.com'}],
#    'manager': [],
#    'editor': [],
#    'reviewer': []},
#   'memberships': [{'id': 1, 'project': 1, 'role': 'owner'},
#    {'id': 3, 'project': 3, 'role': 'owner'},
#    {'id': 7, 'project': 7, 'role': 'owner'},
#    {'id': 9, 'project': 9, 'role': 'owner'}],
#   'is_superuser': False,
#   'is_staff': False,
#   'username': 'mohamed.koubaa@kit.edu',
#   'first_name': 'Anis',
#   'last_name': 'Koubaa',
#   'email': 'mohamed.koubaa@kit.edu',
#   'last_login': '2026-06-15T17:01:48.771582+02:00',
#   'date_joined': '2026-01-20T23:23:13.165496+01:00'},
#  {'id': 2,
#   'groups': [],
#   'role': {'id': 2,
#    'member': [{'id': 1, 'name': 'example.com', 'domain': 'example.com'}],
#    'manager': [],
#    'editor': [],
#    'reviewer': []},
#   'memberships': [{'id': 10, 'project': 10, 'role': 'owner'},
#    {'id': 4, 'project': 4, 'role': 'owner'},
#    {'id': 5, 'project': 5, 'role': 'owner'},
#    {'id': 6, 'project': 6, 'role': 'owner'}],
#   'is_superuser': True,
#   'is_staff': True,
#   'username': 'rdmo',
#   'first_name': '',
#   'last_name': '',
#   'email': 'mohamed.koubaa@kit.edu',
#   'last_login': '2026-06-30T11:52:05.077715+02:00',
#   'date_joined': '2026-01-20T23:27:14+01:00'}]
